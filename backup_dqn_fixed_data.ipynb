# %%
import numpy as np
import random
from collections import deque
import torch
import torch.nn as nn
import torch.optim as optim
import math
import time
import matplotlib.pyplot as plt

# %%
# -------------------------
# Environment & traffic params
# -------------------------
T_p = 1             # time quantum (seconds)
L = 300             # packet/bit size placeholder (not used explicitly)
Q_max = 60          # threshold for high queue
Q_threshold = 40   # threshold for low queue
W_max = 500         # max bandwidth (units treated as service capacity per second)
cycles = 24         # number of cycles per episode (hours)
second_in_hour = 3600            # seconds per cycle (1 hour)
episodes = 1000      # reduce for faster runs; set to 1000 for full run
hours_in_day = 24   # hours in a day

# action levels (same cardinality as original)
W_levels = np.linspace(0, W_max, 26)  # 26 bandwidth choices (0, 20, 40, ... if W_max=500)
mean_arrival_rates = np.array([80, 60, 40, 30, 40, 50, 70, 100, 75, 70, 80, 90, 100, 90, 100, 120, 110, 160, 170, 180, 200, 160, 130, 90,])

# %%
# -------------------------
# Poisson traffic generator (data generation for visualization)
# -------------------------

def generate_poisson_traffic(λ, duration):
    R = np.random.rand(int(λ * duration * 2))
    IAT = -np.log(1 - R) / λ
    arrivals = np.cumsum(IAT)
    return arrivals[arrivals <= duration]

bits_arrival_for_day = []

for hour, λ in enumerate(mean_arrival_rates):
    bits_arrival_for_hour = generate_poisson_traffic(λ, second_in_hour)
    bits_arrival_for_hour += hour * second_in_hour
    bits_arrival_for_day.extend(bits_arrival_for_hour)

time_bins = np.arange(0, hours_in_day*second_in_hour + 1, 1)
bits_arrival_counts, _ = np.histogram(bits_arrival_for_day, bins=time_bins)

# %%
def discretize_state(Qlength):
    # Return 0,1,2 depending on Qlength bins (low/medium/high).
    if Qlength <= Q_threshold:
        return 0
    elif Qlength < Q_max:
        return 1
    else:
        return 2

def encode_state(cycle_idx, Qlength):
    # Return a float32 state vector for the NN: [cycle_norm, one_hot_state0, one_hot_state1, one_hot_state2]
    s = discretize_state(Qlength)
    one_hot = np.zeros(3, dtype=np.float32)
    one_hot[s] = 1.0
    cycle_norm = np.array([cycle_idx / (cycles - 1)], dtype=np.float32)
    return np.concatenate([cycle_norm, one_hot], axis=0)  # shape (4,)

def update_queue(Q, arrivals, u):
    new_packets = arrivals
    Q_new = Q + ((new_packets - u) * T_p / L)
    return max(0, min(Q_new, Q_max + 1))

state_size = 4
action_size = len(W_levels)

# -------------------------
# The per-cycle environment rollout (exact dynamics & reward)
# -------------------------
def env_rollout_one_cycle(cycle_idx, action_bandwidth, Qlength_init):
    Qlength = float(Qlength_init)
    Q_history = []

    for t in range(second_in_hour):
        arrivals_this_sec = int(bits_arrival_counts[cycle_idx * second_in_hour + t])
        Qlength = update_queue(Qlength, arrivals_this_sec, action_bandwidth)
        Q_history.append(Qlength)

    Q_mean = np.mean(Q_history)
    p_violation = np.mean(np.array(Q_history) >= Q_threshold)
    p_drop = np.mean(np.array(Q_history) >= Q_max)

    if p_violation <= 0.1 and p_drop <= 0.01:
        if action_bandwidth == 0:
            reward = Q_mean
        else:
            reward = Q_mean + ( 1 / action_bandwidth)
    elif (p_violation > 0.1 and p_drop <= 0.01) or (p_violation <= 0.1 and p_drop > 0.01):
        reward = 0
    else:
        reward = -1

    return reward, float(Q_history[-1]), p_violation, p_drop

# %%
# -------------------------
# DQN (PyTorch)
# -------------------------
class DQNNet(nn.Module):
    def __init__(self, state_size, action_size):
        super(DQNNet, self).__init__()
        self.fc1 = nn.Linear(state_size, 64)
        self.fc2 = nn.Linear(64, 64)
        self.fc3 = nn.Linear(64, action_size)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return self.fc3(x)

# -------------------------
# Agent
# -------------------------
class DQNAgent:
    def __init__(self, state_size, action_size, lr=1e-3, gamma=0.99, epsilon=1.0, epsilon_min=0.01, epsilon_decay=0.995, memory_size=20000, batch_size=64, target_update_steps=1000):
        self.state_size = state_size
        self.action_size = action_size
        self.gamma = gamma
        self.epsilon = epsilon
        self.epsilon_min = epsilon_min
        self.epsilon_decay = epsilon_decay
        self.batch_size = batch_size
        self.memory = deque(maxlen=memory_size)
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

        self.policy_net = DQNNet(state_size, action_size).to(self.device)
        self.target_net = DQNNet(state_size, action_size).to(self.device)
        self.target_net.load_state_dict(self.policy_net.state_dict())
        self.target_net.eval()

        self.optimizer = optim.Adam(self.policy_net.parameters(), lr=lr)
        self.loss_fn = nn.SmoothL1Loss()  # Huber (less sensitive to outliers)

        self.learn_step_counter = 0
        self.target_update_steps = target_update_steps

    def act(self, state_vec):
        # state_vec: numpy array shape (state_size,)
        if np.random.rand() < self.epsilon:
            return random.randrange(self.action_size)
        s = torch.from_numpy(state_vec).float().unsqueeze(0).to(self.device)  # [1, state_size]
        with torch.no_grad():
            q = self.policy_net(s)
            return int(q.argmax(dim=1).item())

    def remember(self, s, a, r, s2, done):
        self.memory.append((s, a, r, s2, done))

    def sample_batch(self):
        batch = random.sample(self.memory, self.batch_size)
        states, actions, rewards, next_states, dones = zip(*batch)
        states = torch.FloatTensor(np.stack(states)).to(self.device)
        actions = torch.LongTensor(actions).unsqueeze(1).to(self.device)
        rewards = torch.FloatTensor(rewards).unsqueeze(1).to(self.device)
        next_states = torch.FloatTensor(np.stack(next_states)).to(self.device)
        dones = torch.FloatTensor(dones).unsqueeze(1).to(self.device)
        return states, actions, rewards, next_states, dones

    def learn(self):
        if len(self.memory) < max(self.batch_size, 1000):
            return

        states, actions, rewards, next_states, dones = self.sample_batch()

        # current Q(s,a)
        q_values = self.policy_net(states).gather(1, actions)  # [batch,1]

        # target: r + gamma * max_a' Q_target(s', a')
        with torch.no_grad():
            next_q_values = self.target_net(next_states).max(1)[0].unsqueeze(1)  # [batch,1]

        target_q = rewards + self.gamma * next_q_values * (1 - dones)

        loss = self.loss_fn(q_values, target_q)

        self.optimizer.zero_grad()
        loss.backward()
        # gradient clipping for stability
        torch.nn.utils.clip_grad_norm_(self.policy_net.parameters(), 10.0)
        self.optimizer.step()

        # increment step counter and update target network if needed
        self.learn_step_counter += 1
        if self.learn_step_counter % self.target_update_steps == 0:
            self.target_net.load_state_dict(self.policy_net.state_dict())

        # epsilon decay (per learning step)
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

# %%
# -------------------------
# Main training loop
# -------------------------
def train():
    agent = DQNAgent(state_size=state_size, action_size=action_size, lr=1e-3, gamma=0.99, epsilon=1.0, epsilon_min=0.01, epsilon_decay=0.9995, memory_size=20000, batch_size=64, target_update_steps=2000)

    rewards_history = []
    bandwidth_history = []

    for ep in range(1, episodes + 1):
        Qlength = 0.0
        total_bandwidth_episode = 0.0
        total_reward_episode = 0.0

        for cycle_idx in range(cycles):
            state_vec = encode_state(cycle_idx, Qlength)
            action_idx = agent.act(state_vec)
            action_bandwidth = float(W_levels[action_idx])

            reward, Qlength_next, p_viloation, p_drop = env_rollout_one_cycle(cycle_idx, action_bandwidth, Qlength)

            next_state_vec = encode_state(min(cycle_idx + 1, cycles - 1), Qlength_next)
            done = 1.0 if cycle_idx == (cycles - 1) else 0.0

            # store transition (states are small vectors)
            agent.remember(state_vec, action_idx, reward, next_state_vec, done)

            # learn from memory
            agent.learn()

            # update for next cycle
            Qlength = Qlength_next
            total_reward_episode += reward
            total_bandwidth_episode += action_bandwidth

            if ep == 1000:
                print(f"Cycle {cycle_idx} | Action: {action_bandwidth} | Reward: {reward} | TotalRewar: {total_reward_episode} | p_vio: {p_viloation} | p_drop: {p_drop}")

        rewards_history.append(total_reward_episode)
        bandwidth_history.append(total_bandwidth_episode)

        
        print(f"Episode {ep} | TotalReward: {total_reward_episode} | TotalBandwidth: {total_bandwidth_episode}")

    # final save
    torch.save(agent.policy_net.state_dict(), "dqn_policy_final.pth")
    print("Training finished. Saved model to dqn_policy_final.pth")
    return rewards_history, bandwidth_history

if __name__ == "__main__":
    reward_history, bandwidth_history = train()
    plt.plot(reward_history)
    plt.show()
# Out:
# Episode 1 | TotalReward: 11.09583370061309 | TotalBandwidth: 6760.0
# Episode 2 | TotalReward: 2.634069007898421 | TotalBandwidth: 5160.0
# Episode 3 | TotalReward: -3.338889016484602 | TotalBandwidth: 5140.0
# Episode 4 | TotalReward: 0.3837099641927593 | TotalBandwidth: 5860.0
# Episode 5 | TotalReward: -0.33807659181776817 | TotalBandwidth: 5740.0
# Episode 6 | TotalReward: 1.2689142088327527 | TotalBandwidth: 6900.0
# Episode 7 | TotalReward: -0.651328937889807 | TotalBandwidth: 6820.0
# Episode 8 | TotalReward: 2.3215123550483505 | TotalBandwidth: 6480.0
# Episode 9 | TotalReward: -1.977253245487456 | TotalBandwidth: 6000.0
# Episode 10 | TotalReward: -0.1275976860519774 | TotalBandwidth: 6940.0
# Episode 11 | TotalReward: -4.5180355211474135 | TotalBandwidth: 5740.0
# Episode 12 | TotalReward: 6.496479831199368 | TotalBandwidth: 6100.0
# Episode 13 | TotalReward: -3.1148451495645926 | TotalBandwidth: 6660.0
# Episode 14 | TotalReward: 0.494351540441305 | TotalBandwidth: 6000.0
# Episode 15 | TotalReward: 9.551470906790428 | TotalBandwidth: 4800.0
# Episode 16 | TotalReward: -4.455582074541676 | TotalBandwidth: 6120.0
# Episode 17 | TotalReward: 6.756187532281667 | TotalBandwidth: 6300.0
# Episode 18 | TotalReward: -0.08192048692048692 | TotalBandwidth: 5420.0
# Episode 19 | TotalReward: -2.8431705189003162 | TotalBandwidth: 6760.0
# Episode 20 | TotalReward: 0.7234403556165078 | TotalBandwidth: 6140.0
# Episode 21 | TotalReward: -5.748014196095654 | TotalBandwidth: 5700.0
# Episode 22 | TotalReward: -0.31046432026317305 | TotalBandwidth: 5500.0
# Episode 23 | TotalReward: 8.289664814490939 | TotalBandwidth: 6120.0
# Episode 24 | TotalReward: -2.195880677395325 | TotalBandwidth: 5980.0
# Episode 25 | TotalReward: 4.381126881560686 | TotalBandwidth: 5580.0
# Episode 26 | TotalReward: -2.75431042100601 | TotalBandwidth: 4280.0
# Episode 27 | TotalReward: -0.4989363489972207 | TotalBandwidth: 4840.0
# Episode 28 | TotalReward: -1.8379825441276243 | TotalBandwidth: 6220.0
# Episode 29 | TotalReward: 1.0499686125447516 | TotalBandwidth: 5140.0
# Episode 30 | TotalReward: 7.626040663885207 | TotalBandwidth: 4820.0
# Episode 31 | TotalReward: -1.7166798228553377 | TotalBandwidth: 6720.0
# Episode 32 | TotalReward: -1.481929405384205 | TotalBandwidth: 5900.0
# Episode 33 | TotalReward: -2.7798846174780376 | TotalBandwidth: 5960.0
# Episode 34 | TotalReward: -1.3519834227436562 | TotalBandwidth: 6560.0
# Episode 35 | TotalReward: -1.649994909350731 | TotalBandwidth: 5520.0
# Episode 36 | TotalReward: -1.1551716242220125 | TotalBandwidth: 6460.0
# Episode 37 | TotalReward: -1.9763583977142194 | TotalBandwidth: 5700.0
# Episode 38 | TotalReward: -0.08409613267758974 | TotalBandwidth: 6480.0
# Episode 39 | TotalReward: -1.874070369443001 | TotalBandwidth: 5220.0
# Episode 40 | TotalReward: -2.715709133971999 | TotalBandwidth: 5860.0
# Episode 41 | TotalReward: 4.766390292959843 | TotalBandwidth: 5800.0
# Episode 42 | TotalReward: 6.68881695005772 | TotalBandwidth: 3980.0
# Episode 43 | TotalReward: 5.774012154036753 | TotalBandwidth: 6100.0
# Episode 44 | TotalReward: -3.1906208982311317 | TotalBandwidth: 5580.0
# Episode 45 | TotalReward: -0.4685950428203105 | TotalBandwidth: 7340.0
# Episode 46 | TotalReward: -0.5407327203815768 | TotalBandwidth: 6040.0
# Episode 47 | TotalReward: -1.0536384667737 | TotalBandwidth: 5340.0
# Episode 48 | TotalReward: -4.016403616412826 | TotalBandwidth: 5620.0
# Episode 49 | TotalReward: -0.4475801778143913 | TotalBandwidth: 5080.0
# Episode 50 | TotalReward: -0.7745982652824739 | TotalBandwidth: 4940.0
# Episode 51 | TotalReward: -5.204265392041415 | TotalBandwidth: 5440.0
# Episode 52 | TotalReward: -0.19905281840647135 | TotalBandwidth: 6660.0
# Episode 53 | TotalReward: 0.07176950112985603 | TotalBandwidth: 5780.0
# Episode 54 | TotalReward: -1.8924649759539856 | TotalBandwidth: 6560.0
# Episode 55 | TotalReward: -3.6209488048443936 | TotalBandwidth: 5180.0
# Episode 56 | TotalReward: 0.05534305466274065 | TotalBandwidth: 6940.0
# Episode 57 | TotalReward: -5.637297971212617 | TotalBandwidth: 5300.0
# Episode 58 | TotalReward: 2.980166082406843 | TotalBandwidth: 4400.0
# Episode 59 | TotalReward: 4.905982798152999 | TotalBandwidth: 4960.0
# Episode 60 | TotalReward: -2.9199844697642687 | TotalBandwidth: 6800.0
# Episode 61 | TotalReward: 5.590888882783016 | TotalBandwidth: 5980.0
# Episode 62 | TotalReward: -0.8696308847470618 | TotalBandwidth: 6040.0
# Episode 63 | TotalReward: 6.028703602007985 | TotalBandwidth: 4380.0
# Episode 64 | TotalReward: -0.3376840279546157 | TotalBandwidth: 6920.0
# Episode 65 | TotalReward: -1.7210634038192236 | TotalBandwidth: 6460.0
# Episode 66 | TotalReward: 4.713582172637089 | TotalBandwidth: 5940.0
# Episode 67 | TotalReward: 0.4902753809657838 | TotalBandwidth: 5380.0
# Episode 68 | TotalReward: -1.1690956286064997 | TotalBandwidth: 4900.0
# Episode 69 | TotalReward: 11.669672650417198 | TotalBandwidth: 6920.0
# Episode 70 | TotalReward: 1.1577365199355074 | TotalBandwidth: 5300.0
# Episode 71 | TotalReward: 2.3084012787464814 | TotalBandwidth: 6060.0
# Episode 72 | TotalReward: 1.086122961693163 | TotalBandwidth: 5280.0
# Episode 73 | TotalReward: 10.99172163582601 | TotalBandwidth: 5140.0
# Episode 74 | TotalReward: -3.4212626882637127 | TotalBandwidth: 4840.0
# Episode 75 | TotalReward: 7.05527198904155 | TotalBandwidth: 5180.0
# Episode 76 | TotalReward: -0.7179440311298982 | TotalBandwidth: 5380.0
# Episode 77 | TotalReward: -0.7376185747636551 | TotalBandwidth: 6720.0
# Episode 78 | TotalReward: -2.641546293682162 | TotalBandwidth: 5920.0
# Episode 79 | TotalReward: 1.475743736234525 | TotalBandwidth: 5360.0
# Episode 80 | TotalReward: 4.675688879693279 | TotalBandwidth: 5280.0
# Episode 81 | TotalReward: 7.396943824289504 | TotalBandwidth: 5700.0
# Episode 82 | TotalReward: 1.8764953611747688 | TotalBandwidth: 5060.0
# Episode 83 | TotalReward: 5.3532256493506525 | TotalBandwidth: 5720.0
# Episode 84 | TotalReward: 2.283424671490076 | TotalBandwidth: 6560.0
# Episode 85 | TotalReward: 1.17420845257802 | TotalBandwidth: 5820.0
# Episode 86 | TotalReward: 4.276482834012753 | TotalBandwidth: 5520.0
# Episode 87 | TotalReward: 1.1222644992005013 | TotalBandwidth: 5760.0
# Episode 88 | TotalReward: -3.169661440302616 | TotalBandwidth: 5440.0
# Episode 89 | TotalReward: 1.3221590681248563 | TotalBandwidth: 6300.0
# Episode 90 | TotalReward: 6.625226526566248 | TotalBandwidth: 6180.0
# Episode 91 | TotalReward: 0.7844686745198165 | TotalBandwidth: 5000.0
# Episode 92 | TotalReward: 1.8757187482595397 | TotalBandwidth: 5320.0
# Episode 93 | TotalReward: 5.7909806878306895 | TotalBandwidth: 5380.0
# Episode 94 | TotalReward: 1.4782813881107988 | TotalBandwidth: 4960.0
# Episode 95 | TotalReward: 8.585702533837843 | TotalBandwidth: 4800.0
# Episode 96 | TotalReward: 1.6668276214526188 | TotalBandwidth: 6580.0
# Episode 97 | TotalReward: 3.400136916786873 | TotalBandwidth: 5820.0
# Episode 98 | TotalReward: -0.6728111866203977 | TotalBandwidth: 5560.0
# Episode 99 | TotalReward: 2.8762062703922666 | TotalBandwidth: 5540.0
# Episode 100 | TotalReward: 12.876096406371367 | TotalBandwidth: 4920.0
# Episode 101 | TotalReward: 2.4245361317214877 | TotalBandwidth: 5080.0
# Episode 102 | TotalReward: 3.9140057208089862 | TotalBandwidth: 5980.0
# Episode 103 | TotalReward: 9.911638050838036 | TotalBandwidth: 5680.0
# Episode 104 | TotalReward: -2.0438853478765253 | TotalBandwidth: 5000.0
# Episode 105 | TotalReward: -0.047241044616431214 | TotalBandwidth: 5760.0
# Episode 106 | TotalReward: 7.9200733778891195 | TotalBandwidth: 5360.0
# Episode 107 | TotalReward: 0.04034108405329583 | TotalBandwidth: 5440.0
# Episode 108 | TotalReward: 2.445567554641533 | TotalBandwidth: 5800.0
# Episode 109 | TotalReward: 5.732434362778925 | TotalBandwidth: 4400.0
# Episode 110 | TotalReward: 6.777494301994291 | TotalBandwidth: 5100.0
# Episode 111 | TotalReward: 0.5780863449473356 | TotalBandwidth: 6000.0
# Episode 112 | TotalReward: -1.491455699855704 | TotalBandwidth: 6720.0
# Episode 113 | TotalReward: 0.6168343610093607 | TotalBandwidth: 4900.0
# Episode 114 | TotalReward: 0.4768765475809715 | TotalBandwidth: 5520.0
# Episode 115 | TotalReward: -1.8953844155844153 | TotalBandwidth: 5020.0
# Episode 116 | TotalReward: 0.8105874560364328 | TotalBandwidth: 5780.0
# Episode 117 | TotalReward: 2.9816340446590455 | TotalBandwidth: 5080.0
# Episode 118 | TotalReward: 6.49456778028734 | TotalBandwidth: 4500.0
# Episode 119 | TotalReward: 4.361275901875893 | TotalBandwidth: 4700.0
# Episode 120 | TotalReward: 1.1947721500721618 | TotalBandwidth: 4900.0
# Episode 121 | TotalReward: 4.057993783068782 | TotalBandwidth: 4300.0
# Episode 122 | TotalReward: 1.7532771043771083 | TotalBandwidth: 3980.0
# Episode 123 | TotalReward: 8.01202673413327 | TotalBandwidth: 5080.0
# Episode 124 | TotalReward: 2.1839429894179894 | TotalBandwidth: 4900.0
# Episode 125 | TotalReward: 13.216944925444881 | TotalBandwidth: 4580.0
# Episode 126 | TotalReward: 0.037924931549941476 | TotalBandwidth: 3620.0
# Episode 127 | TotalReward: 10.259394680239193 | TotalBandwidth: 2520.0
# Episode 128 | TotalReward: -10.475088614189625 | TotalBandwidth: 2320.0
# Episode 129 | TotalReward: 17.245586546840894 | TotalBandwidth: 2240.0
# Episode 130 | TotalReward: 4.598424338624337 | TotalBandwidth: 2940.0
# Episode 131 | TotalReward: 19.112478939498455 | TotalBandwidth: 3220.0
# Episode 132 | TotalReward: 14.750811270265613 | TotalBandwidth: 4180.0
# Episode 133 | TotalReward: 11.38540870140327 | TotalBandwidth: 3160.0
# Episode 134 | TotalReward: 27.063669444444397 | TotalBandwidth: 2920.0
# Episode 135 | TotalReward: 25.127503703703695 | TotalBandwidth: 2460.0
# Episode 136 | TotalReward: 18.360266817496168 | TotalBandwidth: 3220.0
# Episode 137 | TotalReward: 20.046892171717097 | TotalBandwidth: 3040.0
# Episode 138 | TotalReward: 23.760745046960764 | TotalBandwidth: 3000.0
# Episode 139 | TotalReward: 20.862849446239146 | TotalBandwidth: 4980.0
# Episode 140 | TotalReward: 24.58791581415658 | TotalBandwidth: 2980.0
# Episode 141 | TotalReward: 23.653947344322326 | TotalBandwidth: 3080.0
# Episode 142 | TotalReward: 26.06459796777291 | TotalBandwidth: 2820.0
# Episode 143 | TotalReward: 12.331599206349159 | TotalBandwidth: 3160.0
# Episode 144 | TotalReward: 27.1494382562426 | TotalBandwidth: 2480.0
# Episode 145 | TotalReward: 21.43864985754985 | TotalBandwidth: 3080.0
# Episode 146 | TotalReward: 13.814518473534266 | TotalBandwidth: 3140.0
# Episode 147 | TotalReward: 7.713163398692808 | TotalBandwidth: 3000.0
# Episode 148 | TotalReward: 31.591952777777703 | TotalBandwidth: 2180.0
# Episode 149 | TotalReward: 20.899913443963424 | TotalBandwidth: 2960.0
# Episode 150 | TotalReward: 21.214621296296283 | TotalBandwidth: 3080.0
# Episode 151 | TotalReward: 21.21390568783067 | TotalBandwidth: 2980.0
# Episode 152 | TotalReward: 30.5949209728867 | TotalBandwidth: 3460.0
# Episode 153 | TotalReward: 25.403563359788347 | TotalBandwidth: 2480.0
# Episode 154 | TotalReward: 15.721684333259335 | TotalBandwidth: 2800.0
# Episode 155 | TotalReward: 18.331203968253938 | TotalBandwidth: 3300.0
# Episode 156 | TotalReward: 14.174188625604398 | TotalBandwidth: 3320.0
# Episode 157 | TotalReward: 21.555180714494796 | TotalBandwidth: 3080.0
# Episode 158 | TotalReward: 14.355758080808062 | TotalBandwidth: 3100.0
# Episode 159 | TotalReward: 34.21301220538712 | TotalBandwidth: 2780.0
# Episode 160 | TotalReward: 17.8831796296296 | TotalBandwidth: 2500.0
# Episode 161 | TotalReward: 7.851996443425856 | TotalBandwidth: 3520.0
# Episode 162 | TotalReward: 12.245800916730305 | TotalBandwidth: 4220.0
# Episode 163 | TotalReward: 20.01265370370369 | TotalBandwidth: 2220.0
# Episode 164 | TotalReward: 22.160351851851818 | TotalBandwidth: 2340.0
# Episode 165 | TotalReward: 25.064770199164712 | TotalBandwidth: 3360.0
# Episode 166 | TotalReward: 17.898024275059612 | TotalBandwidth: 3160.0
# Episode 167 | TotalReward: 28.38844361598436 | TotalBandwidth: 2860.0
# Episode 168 | TotalReward: 25.1232917508417 | TotalBandwidth: 2760.0
# Episode 169 | TotalReward: 21.550550925925897 | TotalBandwidth: 2840.0
# Episode 170 | TotalReward: 21.495640828031565 | TotalBandwidth: 3200.0
# Episode 171 | TotalReward: 27.571537645607187 | TotalBandwidth: 3220.0
# Episode 172 | TotalReward: 27.2147381639485 | TotalBandwidth: 3140.0
# Episode 173 | TotalReward: 22.131685185185173 | TotalBandwidth: 2220.0
# Episode 174 | TotalReward: 24.444866524216497 | TotalBandwidth: 2660.0
# Episode 175 | TotalReward: 20.91523184349763 | TotalBandwidth: 2780.0
# Episode 176 | TotalReward: 28.387314898989832 | TotalBandwidth: 2420.0
# Episode 177 | TotalReward: 33.97072199657638 | TotalBandwidth: 2740.0
# Episode 178 | TotalReward: 20.619497061191613 | TotalBandwidth: 2640.0
# Episode 179 | TotalReward: 12.988416015439995 | TotalBandwidth: 3740.0
# Episode 180 | TotalReward: 27.456661943666308 | TotalBandwidth: 2620.0
# Episode 181 | TotalReward: 9.780559650004868 | TotalBandwidth: 2780.0
# Episode 182 | TotalReward: 16.653566137566116 | TotalBandwidth: 2620.0
# Episode 183 | TotalReward: 15.588070209339758 | TotalBandwidth: 2620.0
# Episode 184 | TotalReward: 18.18502605820105 | TotalBandwidth: 2720.0
# Episode 185 | TotalReward: 17.400852875243675 | TotalBandwidth: 2680.0
# Episode 186 | TotalReward: 26.63290198412696 | TotalBandwidth: 2280.0
# Episode 187 | TotalReward: 24.932110451001215 | TotalBandwidth: 2720.0
# Episode 188 | TotalReward: 31.75611836345911 | TotalBandwidth: 3220.0
# Episode 189 | TotalReward: 36.84704164631662 | TotalBandwidth: 2360.0
# Episode 190 | TotalReward: 30.26956802832241 | TotalBandwidth: 2440.0
# Episode 191 | TotalReward: 18.234785582010584 | TotalBandwidth: 3160.0
# Episode 192 | TotalReward: 33.80135645272595 | TotalBandwidth: 3400.0
# Episode 193 | TotalReward: 25.396506536901104 | TotalBandwidth: 3400.0
# Episode 194 | TotalReward: 36.17317433862425 | TotalBandwidth: 2740.0
# Episode 195 | TotalReward: 38.00275038665031 | TotalBandwidth: 2180.0
# Episode 196 | TotalReward: 22.413685950080495 | TotalBandwidth: 3080.0
# Episode 197 | TotalReward: 26.801468097643077 | TotalBandwidth: 3040.0
# Episode 198 | TotalReward: 27.982183164983134 | TotalBandwidth: 2500.0
# Episode 199 | TotalReward: 26.94160269486843 | TotalBandwidth: 2980.0
# Episode 200 | TotalReward: 20.007083472928024 | TotalBandwidth: 2780.0
# Episode 201 | TotalReward: 15.537420238095201 | TotalBandwidth: 2440.0
# Episode 202 | TotalReward: 24.156030991285352 | TotalBandwidth: 2520.0
# Episode 203 | TotalReward: 13.315265598290596 | TotalBandwidth: 3120.0
# Episode 204 | TotalReward: 15.054118734968732 | TotalBandwidth: 2180.0
# Episode 205 | TotalReward: 29.78963325647775 | TotalBandwidth: 3040.0
# Episode 206 | TotalReward: 36.01509202868278 | TotalBandwidth: 2340.0
# Episode 207 | TotalReward: 24.914106878306864 | TotalBandwidth: 3100.0
# Episode 208 | TotalReward: 33.801760488639886 | TotalBandwidth: 2960.0
# Episode 209 | TotalReward: 30.425754761904734 | TotalBandwidth: 2540.0
# Episode 210 | TotalReward: 27.79143608235563 | TotalBandwidth: 2440.0
# Episode 211 | TotalReward: 34.50639176413249 | TotalBandwidth: 2220.0
# Episode 212 | TotalReward: 28.441039927135066 | TotalBandwidth: 2900.0
# Episode 213 | TotalReward: 30.255117592592526 | TotalBandwidth: 2740.0
# Episode 214 | TotalReward: 27.4375476034858 | TotalBandwidth: 2800.0
# Episode 215 | TotalReward: 21.658960820824035 | TotalBandwidth: 3240.0
# Episode 216 | TotalReward: 32.75927017345396 | TotalBandwidth: 2620.0
# Episode 217 | TotalReward: 23.554652046783623 | TotalBandwidth: 3380.0
# Episode 218 | TotalReward: 27.95481485937808 | TotalBandwidth: 3060.0
# Episode 219 | TotalReward: 24.91244262649375 | TotalBandwidth: 3300.0
# Episode 220 | TotalReward: 22.56443863750626 | TotalBandwidth: 3080.0
# Episode 221 | TotalReward: 27.959284551656904 | TotalBandwidth: 2960.0
# Episode 222 | TotalReward: 12.96073632119515 | TotalBandwidth: 3740.0
# Episode 223 | TotalReward: 24.785990221789174 | TotalBandwidth: 3500.0
# Episode 224 | TotalReward: 23.824354520697145 | TotalBandwidth: 2940.0
# Episode 225 | TotalReward: 34.2870305555555 | TotalBandwidth: 3180.0
# Episode 226 | TotalReward: 27.857421296296263 | TotalBandwidth: 3400.0
# Episode 227 | TotalReward: 17.65909267676768 | TotalBandwidth: 3420.0
# Episode 228 | TotalReward: 22.174143518518495 | TotalBandwidth: 3820.0
# Episode 229 | TotalReward: 25.881274045318584 | TotalBandwidth: 3580.0
# Episode 230 | TotalReward: 26.063975873120416 | TotalBandwidth: 3900.0
# Episode 231 | TotalReward: 37.94571759259253 | TotalBandwidth: 2860.0
# Episode 232 | TotalReward: 23.690787962962943 | TotalBandwidth: 3440.0
# Episode 233 | TotalReward: 27.96820312650311 | TotalBandwidth: 2620.0
# Episode 234 | TotalReward: 25.729111195286123 | TotalBandwidth: 3580.0
# Episode 235 | TotalReward: 17.476454713804717 | TotalBandwidth: 2880.0
# Episode 236 | TotalReward: 25.56999457671955 | TotalBandwidth: 2740.0
# Episode 237 | TotalReward: 17.784488095238093 | TotalBandwidth: 3520.0
# Episode 238 | TotalReward: 32.60547222222218 | TotalBandwidth: 2660.0
# Episode 239 | TotalReward: 22.12175370370367 | TotalBandwidth: 3200.0
# Episode 240 | TotalReward: 23.53054731968809 | TotalBandwidth: 3200.0
# Episode 241 | TotalReward: 17.52775817230273 | TotalBandwidth: 3900.0
# Episode 242 | TotalReward: 27.95758398551338 | TotalBandwidth: 3180.0
# Episode 243 | TotalReward: 23.70358518518517 | TotalBandwidth: 2980.0
# Episode 244 | TotalReward: 23.489466798941777 | TotalBandwidth: 4000.0
# Episode 245 | TotalReward: 30.09039590356609 | TotalBandwidth: 2680.0
# Episode 246 | TotalReward: 29.912387134502904 | TotalBandwidth: 2680.0
# Episode 247 | TotalReward: 38.16655043572982 | TotalBandwidth: 3200.0
# Episode 248 | TotalReward: 23.849038825324165 | TotalBandwidth: 2880.0
# Episode 249 | TotalReward: 27.733326851851825 | TotalBandwidth: 2940.0
# Episode 250 | TotalReward: 27.972814814814797 | TotalBandwidth: 2360.0
# Episode 251 | TotalReward: 27.724735185185153 | TotalBandwidth: 3360.0
# Episode 252 | TotalReward: 27.728374074074047 | TotalBandwidth: 2780.0
# Episode 253 | TotalReward: 23.694426851851837 | TotalBandwidth: 3000.0
# Episode 254 | TotalReward: 26.996809259259244 | TotalBandwidth: 3240.0
# Episode 255 | TotalReward: 28.07907609427607 | TotalBandwidth: 2440.0
# Episode 256 | TotalReward: 17.67784731968811 | TotalBandwidth: 3360.0
# Episode 257 | TotalReward: 23.802296380471365 | TotalBandwidth: 2400.0
# Episode 258 | TotalReward: 34.17336580086576 | TotalBandwidth: 3600.0
# Episode 259 | TotalReward: 23.897166329966314 | TotalBandwidth: 3240.0
# Episode 260 | TotalReward: 21.209532144122917 | TotalBandwidth: 3040.0
# Episode 261 | TotalReward: 18.198084779164194 | TotalBandwidth: 2820.0
# Episode 262 | TotalReward: 22.86622121944077 | TotalBandwidth: 3400.0
# Episode 263 | TotalReward: 35.004400168350124 | TotalBandwidth: 3700.0
# Episode 264 | TotalReward: 31.940606511190303 | TotalBandwidth: 2820.0
# Episode 265 | TotalReward: 34.37610841750837 | TotalBandwidth: 3140.0
# Episode 266 | TotalReward: 27.958152441077424 | TotalBandwidth: 3340.0
# Episode 267 | TotalReward: 27.003901936026917 | TotalBandwidth: 2580.0
# Episode 268 | TotalReward: 37.64703863636358 | TotalBandwidth: 2900.0
# Episode 269 | TotalReward: 24.133163888888877 | TotalBandwidth: 3100.0
# Episode 270 | TotalReward: 18.350528537203523 | TotalBandwidth: 3160.0
# Episode 271 | TotalReward: 26.76651397306396 | TotalBandwidth: 2920.0
# Episode 272 | TotalReward: 30.896787121212082 | TotalBandwidth: 2920.0
# Episode 273 | TotalReward: 22.432326010100997 | TotalBandwidth: 3280.0
# Episode 274 | TotalReward: 21.2192877104377 | TotalBandwidth: 3680.0
# Episode 275 | TotalReward: 26.85345550108929 | TotalBandwidth: 2700.0
# Episode 276 | TotalReward: 27.984111869952617 | TotalBandwidth: 3180.0
# Episode 277 | TotalReward: 23.373763727858258 | TotalBandwidth: 3240.0
# Episode 278 | TotalReward: 28.170318518518496 | TotalBandwidth: 2960.0
# Episode 279 | TotalReward: 28.35121767676765 | TotalBandwidth: 2300.0
# Episode 280 | TotalReward: 25.622175264550233 | TotalBandwidth: 2400.0
# Episode 281 | TotalReward: 27.972814814814797 | TotalBandwidth: 2520.0
# Episode 282 | TotalReward: 24.47414617826532 | TotalBandwidth: 3500.0
# Episode 283 | TotalReward: 33.94015304232801 | TotalBandwidth: 2380.0
# Episode 284 | TotalReward: 24.694433465608444 | TotalBandwidth: 2680.0
# Episode 285 | TotalReward: 27.577285269360253 | TotalBandwidth: 2520.0
# Episode 286 | TotalReward: 27.578036195286177 | TotalBandwidth: 2540.0
# Episode 287 | TotalReward: 27.578036195286177 | TotalBandwidth: 2440.0
# Episode 288 | TotalReward: 33.93940211640208 | TotalBandwidth: 2400.0
# Episode 289 | TotalReward: 27.09550833333331 | TotalBandwidth: 2380.0
# Episode 290 | TotalReward: 24.248694444444425 | TotalBandwidth: 2700.0
# Episode 291 | TotalReward: 27.965756481481463 | TotalBandwidth: 2740.0
# Episode 292 | TotalReward: 33.93870767195763 | TotalBandwidth: 2340.0
# Episode 293 | TotalReward: 36.626331914381865 | TotalBandwidth: 2460.0
# Episode 294 | TotalReward: 31.134612301587264 | TotalBandwidth: 2440.0
# Episode 295 | TotalReward: 31.865146354831676 | TotalBandwidth: 3200.0
# Episode 296 | TotalReward: 39.983332853598554 | TotalBandwidth: 2580.0
# Episode 297 | TotalReward: 42.59622711640202 | TotalBandwidth: 2340.0
# Episode 298 | TotalReward: 35.92999933862426 | TotalBandwidth: 2580.0
# Episode 299 | TotalReward: 42.59622711640202 | TotalBandwidth: 2360.0
# Episode 300 | TotalReward: 36.99110767195758 | TotalBandwidth: 2260.0
# Episode 301 | TotalReward: 30.701501274651253 | TotalBandwidth: 2440.0
# Episode 302 | TotalReward: 39.900020634920544 | TotalBandwidth: 2160.0
# Episode 303 | TotalReward: 43.091951190476095 | TotalBandwidth: 2320.0
# Episode 304 | TotalReward: 37.22943553391045 | TotalBandwidth: 2420.0
# Episode 305 | TotalReward: 35.028583597883554 | TotalBandwidth: 2360.0
# Episode 306 | TotalReward: 40.17736693121684 | TotalBandwidth: 2580.0
# Episode 307 | TotalReward: 28.520227116402094 | TotalBandwidth: 2240.0
# Episode 308 | TotalReward: 32.56820211640208 | TotalBandwidth: 2540.0
# Episode 309 | TotalReward: 43.96995211640203 | TotalBandwidth: 2320.0
# Episode 310 | TotalReward: 35.028583597883554 | TotalBandwidth: 2340.0
# Episode 311 | TotalReward: 42.081294793169704 | TotalBandwidth: 2360.0
# Episode 312 | TotalReward: 31.3038907796452 | TotalBandwidth: 2680.0
# Episode 313 | TotalReward: 35.028583597883554 | TotalBandwidth: 2380.0
# Episode 314 | TotalReward: 36.04236230158726 | TotalBandwidth: 2460.0
# Episode 315 | TotalReward: 35.03170590428087 | TotalBandwidth: 2460.0
# Episode 316 | TotalReward: 43.96995211640203 | TotalBandwidth: 2320.0
# Episode 317 | TotalReward: 33.503614153439116 | TotalBandwidth: 2560.0
# Episode 318 | TotalReward: 33.30488822751318 | TotalBandwidth: 2400.0
# Episode 319 | TotalReward: 27.55802622938065 | TotalBandwidth: 2780.0
# Episode 320 | TotalReward: 31.878467724867722 | TotalBandwidth: 2640.0
# Episode 321 | TotalReward: 33.96574616402113 | TotalBandwidth: 2880.0
# Episode 322 | TotalReward: 35.03170590428087 | TotalBandwidth: 2500.0
# Episode 323 | TotalReward: 35.062595899470885 | TotalBandwidth: 2360.0
# Episode 324 | TotalReward: 35.906584523809485 | TotalBandwidth: 2340.0
# Episode 325 | TotalReward: 38.82271463443954 | TotalBandwidth: 2660.0
# Episode 326 | TotalReward: 34.203053306878246 | TotalBandwidth: 2220.0
# Episode 327 | TotalReward: 36.04236230158726 | TotalBandwidth: 2300.0
# Episode 328 | TotalReward: 36.04236230158726 | TotalBandwidth: 2420.0
# Episode 329 | TotalReward: 36.928437674362605 | TotalBandwidth: 2800.0
# Episode 330 | TotalReward: 30.300949603174608 | TotalBandwidth: 2400.0
# Episode 331 | TotalReward: 36.04236230158726 | TotalBandwidth: 2360.0
# Episode 332 | TotalReward: 35.028583597883554 | TotalBandwidth: 2340.0
# Episode 333 | TotalReward: 35.028583597883554 | TotalBandwidth: 2240.0
# Episode 334 | TotalReward: 36.04236230158726 | TotalBandwidth: 2420.0
# Episode 335 | TotalReward: 35.24702248677245 | TotalBandwidth: 2500.0
# Episode 336 | TotalReward: 32.599540079365056 | TotalBandwidth: 2480.0
# Episode 337 | TotalReward: 33.27051584426035 | TotalBandwidth: 2840.0
# Episode 338 | TotalReward: 32.13092460317458 | TotalBandwidth: 2760.0
# Episode 339 | TotalReward: 33.972889417989386 | TotalBandwidth: 2400.0
# Episode 340 | TotalReward: 25.490620851370856 | TotalBandwidth: 2560.0
# Episode 341 | TotalReward: 33.972889417989386 | TotalBandwidth: 2420.0
# Episode 342 | TotalReward: 36.92036322751319 | TotalBandwidth: 2360.0
# Episode 343 | TotalReward: 33.972889417989386 | TotalBandwidth: 2240.0
# Episode 344 | TotalReward: 32.95911071428568 | TotalBandwidth: 2260.0
# Episode 345 | TotalReward: 37.014897751322664 | TotalBandwidth: 2820.0
# Episode 346 | TotalReward: 34.85089034391532 | TotalBandwidth: 2360.0
# Episode 347 | TotalReward: 32.95911071428568 | TotalBandwidth: 2320.0
# Episode 348 | TotalReward: 39.25387063492054 | TotalBandwidth: 2320.0
# Episode 349 | TotalReward: 36.37140475172969 | TotalBandwidth: 2240.0
# Episode 350 | TotalReward: 36.04236230158726 | TotalBandwidth: 2280.0
# Episode 351 | TotalReward: 30.300949603174608 | TotalBandwidth: 2280.0
# Episode 352 | TotalReward: 40.18454086284077 | TotalBandwidth: 2440.0
# Episode 353 | TotalReward: 36.92036322751319 | TotalBandwidth: 2320.0
# Episode 354 | TotalReward: 33.972889417989386 | TotalBandwidth: 2400.0
# Episode 355 | TotalReward: 34.05555052910051 | TotalBandwidth: 2380.0
# Episode 356 | TotalReward: 32.14839018288472 | TotalBandwidth: 2740.0
# Episode 357 | TotalReward: 36.04236230158726 | TotalBandwidth: 2220.0
# Episode 358 | TotalReward: 34.31411084656081 | TotalBandwidth: 2460.0
# Episode 359 | TotalReward: 34.335779232804185 | TotalBandwidth: 2180.0
# Episode 360 | TotalReward: 39.068037566137484 | TotalBandwidth: 2560.0
# Episode 361 | TotalReward: 26.94212645502642 | TotalBandwidth: 2800.0
# Episode 362 | TotalReward: 32.16377089947086 | TotalBandwidth: 2380.0
# Episode 363 | TotalReward: 36.92036322751319 | TotalBandwidth: 2320.0
# Episode 364 | TotalReward: 34.617838492063484 | TotalBandwidth: 2360.0
# Episode 365 | TotalReward: 32.22626534391535 | TotalBandwidth: 2460.0
# Episode 366 | TotalReward: 33.72736719576719 | TotalBandwidth: 2280.0
# Episode 367 | TotalReward: 36.04236230158726 | TotalBandwidth: 2320.0
# Episode 368 | TotalReward: 41.89752830687822 | TotalBandwidth: 2280.0
# Episode 369 | TotalReward: 34.30071729323303 | TotalBandwidth: 2400.0
# Episode 370 | TotalReward: 37.052175529100445 | TotalBandwidth: 2140.0
# Episode 371 | TotalReward: 32.59293487253488 | TotalBandwidth: 2400.0
# Episode 372 | TotalReward: 32.95911071428568 | TotalBandwidth: 2420.0
# Episode 373 | TotalReward: 34.018105904280866 | TotalBandwidth: 2520.0
# Episode 374 | TotalReward: 34.85089034391532 | TotalBandwidth: 2400.0
# Episode 375 | TotalReward: 33.83711164021161 | TotalBandwidth: 2420.0
# Episode 376 | TotalReward: 32.68388927553925 | TotalBandwidth: 2340.0
# Episode 377 | TotalReward: 24.770188217338223 | TotalBandwidth: 2340.0
# Episode 378 | TotalReward: 30.522064275539286 | TotalBandwidth: 2200.0
# Episode 379 | TotalReward: 31.811064417989428 | TotalBandwidth: 1940.0
# Episode 380 | TotalReward: 31.811064417989428 | TotalBandwidth: 2160.0
# Episode 381 | TotalReward: 30.64276904761906 | TotalBandwidth: 2100.0
# Episode 382 | TotalReward: 31.811064417989428 | TotalBandwidth: 2120.0
# Episode 383 | TotalReward: 41.49322341269832 | TotalBandwidth: 2100.0
# Episode 384 | TotalReward: 30.965886640211632 | TotalBandwidth: 2240.0
# Episode 385 | TotalReward: 30.522064275539286 | TotalBandwidth: 2120.0
# Episode 386 | TotalReward: 31.811064417989428 | TotalBandwidth: 2180.0
# Episode 387 | TotalReward: 30.189046922862683 | TotalBandwidth: 2420.0
# Episode 388 | TotalReward: 31.77773571428568 | TotalBandwidth: 2420.0
# Episode 389 | TotalReward: 31.7743540717736 | TotalBandwidth: 2480.0
# Episode 390 | TotalReward: 31.777180158730122 | TotalBandwidth: 2220.0
# Episode 391 | TotalReward: 31.777180158730122 | TotalBandwidth: 2200.0
# Episode 392 | TotalReward: 31.775751587301553 | TotalBandwidth: 2460.0
# Episode 393 | TotalReward: 31.775513492063457 | TotalBandwidth: 2300.0
# Episode 394 | TotalReward: 31.774263492063458 | TotalBandwidth: 2620.0
# Episode 395 | TotalReward: 39.837631084656 | TotalBandwidth: 2420.0
# Episode 396 | TotalReward: 30.62613386243387 | TotalBandwidth: 2640.0
# Episode 397 | TotalReward: 39.8391191798941 | TotalBandwidth: 2340.0
# Episode 398 | TotalReward: 33.56540701058201 | TotalBandwidth: 2300.0
# Episode 399 | TotalReward: 39.83971441798934 | TotalBandwidth: 2340.0
# Episode 400 | TotalReward: 39.83967473544965 | TotalBandwidth: 2120.0
# Episode 401 | TotalReward: 32.144103306878264 | TotalBandwidth: 2160.0
# Episode 402 | TotalReward: 31.775513492063457 | TotalBandwidth: 2180.0
# Episode 403 | TotalReward: 37.32357075702068 | TotalBandwidth: 2460.0
# Episode 404 | TotalReward: 39.83772166436615 | TotalBandwidth: 2280.0
# Episode 405 | TotalReward: 31.7743540717736 | TotalBandwidth: 2600.0
# Episode 406 | TotalReward: 31.775305158730124 | TotalBandwidth: 2340.0
# Episode 407 | TotalReward: 39.841658862433775 | TotalBandwidth: 2240.0
# Episode 408 | TotalReward: 31.79081534391531 | TotalBandwidth: 2220.0
# Episode 409 | TotalReward: 31.775121335200712 | TotalBandwidth: 2500.0
# Episode 410 | TotalReward: 31.775513492063457 | TotalBandwidth: 2360.0
# Episode 411 | TotalReward: 39.840547751322674 | TotalBandwidth: 2020.0
# Episode 412 | TotalReward: 39.84179775132267 | TotalBandwidth: 2240.0
# Episode 413 | TotalReward: 31.774680158730124 | TotalBandwidth: 2660.0
# Episode 414 | TotalReward: 31.778430158730124 | TotalBandwidth: 2240.0
# Episode 415 | TotalReward: 34.646324687349626 | TotalBandwidth: 2220.0
# Episode 416 | TotalReward: 39.84179775132267 | TotalBandwidth: 2120.0
# Episode 417 | TotalReward: 39.8391191798941 | TotalBandwidth: 2460.0
# Episode 418 | TotalReward: 31.7749579365079 | TotalBandwidth: 2420.0
# Episode 419 | TotalReward: 31.775867592592558 | TotalBandwidth: 2540.0
# Episode 420 | TotalReward: 39.84310423280415 | TotalBandwidth: 2260.0
# Episode 421 | TotalReward: 41.91127063492055 | TotalBandwidth: 2080.0
# Episode 422 | TotalReward: 39.07614034391526 | TotalBandwidth: 2300.0
# Episode 423 | TotalReward: 39.837631084656 | TotalBandwidth: 2800.0
# Episode 424 | TotalReward: 39.88889034391526 | TotalBandwidth: 2000.0
# Episode 425 | TotalReward: 30.07511256613756 | TotalBandwidth: 2760.0
# Episode 426 | TotalReward: 39.84179775132267 | TotalBandwidth: 2140.0
# Episode 427 | TotalReward: 41.912577116402026 | TotalBandwidth: 2380.0
# Episode 428 | TotalReward: 36.69237367724859 | TotalBandwidth: 2400.0
# Episode 429 | TotalReward: 35.14175324331352 | TotalBandwidth: 2800.0
# Episode 430 | TotalReward: 39.83817933027004 | TotalBandwidth: 2520.0
# Episode 431 | TotalReward: 39.838881084656 | TotalBandwidth: 2280.0
# Episode 432 | TotalReward: 40.71648985371919 | TotalBandwidth: 2220.0
# Episode 433 | TotalReward: 39.83772166436615 | TotalBandwidth: 2360.0
# Episode 434 | TotalReward: 39.84179775132267 | TotalBandwidth: 2100.0
# Episode 435 | TotalReward: 39.841658862433775 | TotalBandwidth: 2120.0
# Episode 436 | TotalReward: 41.9118261904761 | TotalBandwidth: 2060.0
# Episode 437 | TotalReward: 41.91127063492055 | TotalBandwidth: 2220.0
# Episode 438 | TotalReward: 43.091951190476095 | TotalBandwidth: 1960.0
# Episode 439 | TotalReward: 41.912577116402026 | TotalBandwidth: 1940.0
# Episode 440 | TotalReward: 39.83817933027004 | TotalBandwidth: 2340.0
# Episode 441 | TotalReward: 34.345832936507925 | TotalBandwidth: 2520.0
# Episode 442 | TotalReward: 43.091951190476095 | TotalBandwidth: 2260.0
# Episode 443 | TotalReward: 39.83772166436615 | TotalBandwidth: 2540.0
# Episode 444 | TotalReward: 39.83772166436615 | TotalBandwidth: 2600.0
# Episode 445 | TotalReward: 38.07805062656634 | TotalBandwidth: 2840.0
# Episode 446 | TotalReward: 30.993732010582 | TotalBandwidth: 2460.0
# Episode 447 | TotalReward: 39.837655594459925 | TotalBandwidth: 2600.0
# Episode 448 | TotalReward: 39.84179775132267 | TotalBandwidth: 2420.0
# Episode 449 | TotalReward: 43.091951190476095 | TotalBandwidth: 2240.0
# Episode 450 | TotalReward: 31.776069047619014 | TotalBandwidth: 2440.0
# Episode 451 | TotalReward: 32.49926534391528 | TotalBandwidth: 2200.0
# Episode 452 | TotalReward: 41.91113174603165 | TotalBandwidth: 2260.0
# Episode 453 | TotalReward: 39.837928703703625 | TotalBandwidth: 2480.0
# Episode 454 | TotalReward: 43.091951190476095 | TotalBandwidth: 2140.0
# Episode 455 | TotalReward: 33.09516521164017 | TotalBandwidth: 2400.0
# Episode 456 | TotalReward: 39.84235330687822 | TotalBandwidth: 2260.0
# Episode 457 | TotalReward: 35.73201507936504 | TotalBandwidth: 2460.0
# Episode 458 | TotalReward: 41.912577116402026 | TotalBandwidth: 1940.0
# Episode 459 | TotalReward: 37.50002182539675 | TotalBandwidth: 2200.0
# Episode 460 | TotalReward: 31.731235714285724 | TotalBandwidth: 2440.0
# Episode 461 | TotalReward: 34.53285952380948 | TotalBandwidth: 2400.0
# Episode 462 | TotalReward: 33.85642619047614 | TotalBandwidth: 3640.0
# Episode 463 | TotalReward: 37.15602526455018 | TotalBandwidth: 2620.0
# Episode 464 | TotalReward: 41.408644386933425 | TotalBandwidth: 3000.0
# Episode 465 | TotalReward: 42.59327619047609 | TotalBandwidth: 2400.0
# Episode 466 | TotalReward: 39.57443637566128 | TotalBandwidth: 2760.0
# Episode 467 | TotalReward: 31.72811071428572 | TotalBandwidth: 2720.0
# Episode 468 | TotalReward: 40.526754232804144 | TotalBandwidth: 2360.0
# Episode 469 | TotalReward: 41.4556121405566 | TotalBandwidth: 2600.0
# Episode 470 | TotalReward: 38.848488227513144 | TotalBandwidth: 2340.0
# Episode 471 | TotalReward: 39.992194047618966 | TotalBandwidth: 2440.0
# Episode 472 | TotalReward: 38.848488227513144 | TotalBandwidth: 2420.0
# Episode 473 | TotalReward: 43.091951190476095 | TotalBandwidth: 2160.0
# Episode 474 | TotalReward: 32.22404312169313 | TotalBandwidth: 2540.0
# Episode 475 | TotalReward: 40.526754232804144 | TotalBandwidth: 2300.0
# Episode 476 | TotalReward: 43.089000264550165 | TotalBandwidth: 2360.0
# Episode 477 | TotalReward: 43.091951190476095 | TotalBandwidth: 2300.0
# Episode 478 | TotalReward: 41.01952738095229 | TotalBandwidth: 2460.0
# Episode 479 | TotalReward: 42.59622711640202 | TotalBandwidth: 2320.0
# Episode 480 | TotalReward: 41.02247830687822 | TotalBandwidth: 2340.0
# Episode 481 | TotalReward: 42.59622711640202 | TotalBandwidth: 2240.0
# Episode 482 | TotalReward: 40.526754232804144 | TotalBandwidth: 2280.0
# Episode 483 | TotalReward: 43.091951190476095 | TotalBandwidth: 2080.0
# Episode 484 | TotalReward: 32.170162566137556 | TotalBandwidth: 2940.0
# Episode 485 | TotalReward: 41.02247830687822 | TotalBandwidth: 2400.0
# Episode 486 | TotalReward: 43.091951190476095 | TotalBandwidth: 2260.0
# Episode 487 | TotalReward: 41.02247830687822 | TotalBandwidth: 2440.0
# Episode 488 | TotalReward: 43.091951190476095 | TotalBandwidth: 2360.0
# Episode 489 | TotalReward: 43.091951190476095 | TotalBandwidth: 2220.0
# Episode 490 | TotalReward: 41.02247830687822 | TotalBandwidth: 2340.0
# Episode 491 | TotalReward: 43.091951190476095 | TotalBandwidth: 2120.0
# Episode 492 | TotalReward: 43.091951190476095 | TotalBandwidth: 2220.0
# Episode 493 | TotalReward: 43.091951190476095 | TotalBandwidth: 2260.0
# Episode 494 | TotalReward: 43.091951190476095 | TotalBandwidth: 2200.0
# Episode 495 | TotalReward: 43.091951190476095 | TotalBandwidth: 2320.0
# Episode 496 | TotalReward: 43.091951190476095 | TotalBandwidth: 2340.0
# Episode 497 | TotalReward: 43.091951190476095 | TotalBandwidth: 2200.0
# Episode 498 | TotalReward: 41.02247830687822 | TotalBandwidth: 2380.0
# Episode 499 | TotalReward: 43.091951190476095 | TotalBandwidth: 2260.0
# Episode 500 | TotalReward: 41.02247830687822 | TotalBandwidth: 2440.0
# Episode 501 | TotalReward: 42.59622711640202 | TotalBandwidth: 2160.0
# Episode 502 | TotalReward: 43.091951190476095 | TotalBandwidth: 2300.0
# Episode 503 | TotalReward: 43.091951190476095 | TotalBandwidth: 2240.0
# Episode 504 | TotalReward: 43.091951190476095 | TotalBandwidth: 2380.0
# Episode 505 | TotalReward: 41.02247830687822 | TotalBandwidth: 2060.0
# Episode 506 | TotalReward: 43.091951190476095 | TotalBandwidth: 2420.0
# Episode 507 | TotalReward: 43.091951190476095 | TotalBandwidth: 2220.0
# Episode 508 | TotalReward: 43.091951190476095 | TotalBandwidth: 2140.0
# Episode 509 | TotalReward: 43.091951190476095 | TotalBandwidth: 2220.0
# Episode 510 | TotalReward: 43.091951190476095 | TotalBandwidth: 2400.0
# Episode 511 | TotalReward: 43.091951190476095 | TotalBandwidth: 2300.0
# Episode 512 | TotalReward: 43.091951190476095 | TotalBandwidth: 2280.0
# Episode 513 | TotalReward: 43.091951190476095 | TotalBandwidth: 2360.0
# Episode 514 | TotalReward: 32.76683121693119 | TotalBandwidth: 2360.0
# Episode 515 | TotalReward: 43.091951190476095 | TotalBandwidth: 2260.0
# Episode 516 | TotalReward: 30.677242195767207 | TotalBandwidth: 2840.0
# Episode 517 | TotalReward: 43.091951190476095 | TotalBandwidth: 2180.0
# Episode 518 | TotalReward: 43.091951190476095 | TotalBandwidth: 2200.0
# Episode 519 | TotalReward: 43.091951190476095 | TotalBandwidth: 2400.0
# Episode 520 | TotalReward: 43.089000264550165 | TotalBandwidth: 2420.0
# Episode 521 | TotalReward: 41.01952738095229 | TotalBandwidth: 2380.0
# Episode 522 | TotalReward: 43.091951190476095 | TotalBandwidth: 2140.0
# Episode 523 | TotalReward: 43.091951190476095 | TotalBandwidth: 2240.0
# Episode 524 | TotalReward: 42.59622711640202 | TotalBandwidth: 2160.0
# Episode 525 | TotalReward: 43.091951190476095 | TotalBandwidth: 2340.0
# Episode 526 | TotalReward: 41.77896600529091 | TotalBandwidth: 2300.0
# Episode 527 | TotalReward: 43.091951190476095 | TotalBandwidth: 2220.0
# Episode 528 | TotalReward: 43.091951190476095 | TotalBandwidth: 2320.0
# Episode 529 | TotalReward: 43.091951190476095 | TotalBandwidth: 2300.0
# Episode 530 | TotalReward: 43.091951190476095 | TotalBandwidth: 2300.0
# Episode 531 | TotalReward: 43.091951190476095 | TotalBandwidth: 2280.0
# Episode 532 | TotalReward: 43.091951190476095 | TotalBandwidth: 2340.0
# Episode 533 | TotalReward: 41.9096261904761 | TotalBandwidth: 2400.0
# Episode 534 | TotalReward: 43.091951190476095 | TotalBandwidth: 2280.0
# Episode 535 | TotalReward: 43.091951190476095 | TotalBandwidth: 2220.0
# Episode 536 | TotalReward: 43.091951190476095 | TotalBandwidth: 2300.0
# Episode 537 | TotalReward: 43.091951190476095 | TotalBandwidth: 2360.0
# Episode 538 | TotalReward: 43.091951190476095 | TotalBandwidth: 2140.0
# Episode 539 | TotalReward: 43.091951190476095 | TotalBandwidth: 2360.0
# Episode 540 | TotalReward: 43.091951190476095 | TotalBandwidth: 2220.0
# Episode 541 | TotalReward: 41.77896600529091 | TotalBandwidth: 2440.0
# Episode 542 | TotalReward: 38.50547711640202 | TotalBandwidth: 2480.0
# Episode 543 | TotalReward: 26.455617470466443 | TotalBandwidth: 2700.0
# Episode 544 | TotalReward: 38.135369708994624 | TotalBandwidth: 2480.0
# Episode 545 | TotalReward: 31.811064417989428 | TotalBandwidth: 2120.0
# Episode 546 | TotalReward: 31.265043121693132 | TotalBandwidth: 2340.0
# Episode 547 | TotalReward: 38.25055158730151 | TotalBandwidth: 2400.0
# Episode 548 | TotalReward: 37.53163399470891 | TotalBandwidth: 2620.0
# Episode 549 | TotalReward: 41.77896600529091 | TotalBandwidth: 2480.0
# Episode 550 | TotalReward: 41.77896600529091 | TotalBandwidth: 2300.0
# Episode 551 | TotalReward: 41.77896600529091 | TotalBandwidth: 2220.0
# Episode 552 | TotalReward: 42.829153968253884 | TotalBandwidth: 2160.0
# Episode 553 | TotalReward: 33.832732671957636 | TotalBandwidth: 2040.0
# Episode 554 | TotalReward: 41.63061148758641 | TotalBandwidth: 3020.0
# Episode 555 | TotalReward: 42.80284656084648 | TotalBandwidth: 2680.0
# Episode 556 | TotalReward: 43.091951190476095 | TotalBandwidth: 2360.0
# Episode 557 | TotalReward: 34.22689243626743 | TotalBandwidth: 2340.0
# Episode 558 | TotalReward: 43.989221560846474 | TotalBandwidth: 2160.0
# Episode 559 | TotalReward: 32.578028306878316 | TotalBandwidth: 2220.0
# Episode 560 | TotalReward: 30.20504682539682 | TotalBandwidth: 2120.0
# Episode 561 | TotalReward: 39.17125220057711 | TotalBandwidth: 2240.0
# Episode 562 | TotalReward: 43.989221560846474 | TotalBandwidth: 2340.0
# Episode 563 | TotalReward: 43.989221560846474 | TotalBandwidth: 2040.0
# Episode 564 | TotalReward: 40.87033082010573 | TotalBandwidth: 2060.0
# Episode 565 | TotalReward: 41.912577116402026 | TotalBandwidth: 2200.0
# Episode 566 | TotalReward: 43.989221560846474 | TotalBandwidth: 2300.0
# Episode 567 | TotalReward: 43.989221560846474 | TotalBandwidth: 2300.0
# Episode 568 | TotalReward: 40.61968343685293 | TotalBandwidth: 2540.0
# Episode 569 | TotalReward: 42.80163883137788 | TotalBandwidth: 2680.0
# Episode 570 | TotalReward: 41.59443187830679 | TotalBandwidth: 2360.0
# Episode 571 | TotalReward: 43.989221560846474 | TotalBandwidth: 2000.0
# Episode 572 | TotalReward: 29.13622288359789 | TotalBandwidth: 2440.0
# Episode 573 | TotalReward: 43.989221560846474 | TotalBandwidth: 2280.0
# Episode 574 | TotalReward: 43.989221560846474 | TotalBandwidth: 2080.0
# Episode 575 | TotalReward: 43.989221560846474 | TotalBandwidth: 2180.0
# Episode 576 | TotalReward: 43.989221560846474 | TotalBandwidth: 2000.0
# Episode 577 | TotalReward: 43.989221560846474 | TotalBandwidth: 1980.0
# Episode 578 | TotalReward: 43.989221560846474 | TotalBandwidth: 2000.0
# Episode 579 | TotalReward: 43.989221560846474 | TotalBandwidth: 2240.0
# Episode 580 | TotalReward: 43.989221560846474 | TotalBandwidth: 2160.0
# Episode 581 | TotalReward: 43.989221560846474 | TotalBandwidth: 2200.0
# Episode 582 | TotalReward: 43.989221560846474 | TotalBandwidth: 2240.0
# Episode 583 | TotalReward: 43.989221560846474 | TotalBandwidth: 2340.0
# Episode 584 | TotalReward: 35.92585396825393 | TotalBandwidth: 2220.0
# Episode 585 | TotalReward: 43.989221560846474 | TotalBandwidth: 2220.0
# Episode 586 | TotalReward: 43.989221560846474 | TotalBandwidth: 2100.0
# Episode 587 | TotalReward: 43.989221560846474 | TotalBandwidth: 2000.0
# Episode 588 | TotalReward: 42.809847486772405 | TotalBandwidth: 2260.0
# Episode 589 | TotalReward: 42.809847486772405 | TotalBandwidth: 2220.0
# Episode 590 | TotalReward: 43.989221560846474 | TotalBandwidth: 2080.0
# Episode 591 | TotalReward: 43.989221560846474 | TotalBandwidth: 2060.0
# Episode 592 | TotalReward: 43.989221560846474 | TotalBandwidth: 2140.0
# Episode 593 | TotalReward: 43.989221560846474 | TotalBandwidth: 2180.0
# Episode 594 | TotalReward: 33.87494907407408 | TotalBandwidth: 2580.0
# Episode 595 | TotalReward: 42.809847486772405 | TotalBandwidth: 2080.0
# Episode 596 | TotalReward: 42.809847486772405 | TotalBandwidth: 1940.0
# Episode 597 | TotalReward: 42.809847486772405 | TotalBandwidth: 2440.0
# Episode 598 | TotalReward: 42.803311072180556 | TotalBandwidth: 2540.0
# Episode 599 | TotalReward: 42.81726415343907 | TotalBandwidth: 2160.0
# Episode 600 | TotalReward: 43.989221560846474 | TotalBandwidth: 2140.0
# Episode 601 | TotalReward: 44.867222486772405 | TotalBandwidth: 2200.0
# Episode 602 | TotalReward: 43.989221560846474 | TotalBandwidth: 2020.0
# Episode 603 | TotalReward: 43.989221560846474 | TotalBandwidth: 2160.0
# Episode 604 | TotalReward: 43.989221560846474 | TotalBandwidth: 2200.0
# Episode 605 | TotalReward: 43.989221560846474 | TotalBandwidth: 2120.0
# Episode 606 | TotalReward: 44.867222486772405 | TotalBandwidth: 1980.0
# Episode 607 | TotalReward: 43.989221560846474 | TotalBandwidth: 2180.0
# Episode 608 | TotalReward: 43.989221560846474 | TotalBandwidth: 2060.0
# Episode 609 | TotalReward: 42.80622906571977 | TotalBandwidth: 2380.0
# Episode 610 | TotalReward: 35.10462063492063 | TotalBandwidth: 2480.0
# Episode 611 | TotalReward: 43.989221560846474 | TotalBandwidth: 2180.0
# Episode 612 | TotalReward: 43.989221560846474 | TotalBandwidth: 2080.0
# Episode 613 | TotalReward: 42.80498331298323 | TotalBandwidth: 2260.0
# Episode 614 | TotalReward: 43.989221560846474 | TotalBandwidth: 1960.0
# Episode 615 | TotalReward: 43.989221560846474 | TotalBandwidth: 2340.0
# Episode 616 | TotalReward: 42.809847486772405 | TotalBandwidth: 2400.0
# Episode 617 | TotalReward: 43.989221560846474 | TotalBandwidth: 2160.0
# Episode 618 | TotalReward: 42.80163883137788 | TotalBandwidth: 2660.0
# Episode 619 | TotalReward: 43.989221560846474 | TotalBandwidth: 2260.0
# Episode 620 | TotalReward: 43.989221560846474 | TotalBandwidth: 2020.0
# Episode 621 | TotalReward: 43.989221560846474 | TotalBandwidth: 2120.0
# Episode 622 | TotalReward: 43.989221560846474 | TotalBandwidth: 2000.0
# Episode 623 | TotalReward: 43.989221560846474 | TotalBandwidth: 2120.0
# Episode 624 | TotalReward: 43.989221560846474 | TotalBandwidth: 2220.0
# Episode 625 | TotalReward: 42.80498331298323 | TotalBandwidth: 2380.0
# Episode 626 | TotalReward: 39.74784748677241 | TotalBandwidth: 2160.0
# Episode 627 | TotalReward: 40.669416646316535 | TotalBandwidth: 2840.0
# Episode 628 | TotalReward: 46.47932063492051 | TotalBandwidth: 1940.0
# Episode 629 | TotalReward: 47.87231507936497 | TotalBandwidth: 2360.0
# Episode 630 | TotalReward: 47.869364153439044 | TotalBandwidth: 2340.0
# Episode 631 | TotalReward: 47.869364153439044 | TotalBandwidth: 2140.0
# Episode 632 | TotalReward: 43.986270634920544 | TotalBandwidth: 2240.0
# Episode 633 | TotalReward: 43.986270634920544 | TotalBandwidth: 2260.0
# Episode 634 | TotalReward: 43.989221560846474 | TotalBandwidth: 2120.0
# Episode 635 | TotalReward: 47.869364153439044 | TotalBandwidth: 2140.0
# Episode 636 | TotalReward: 47.869364153439044 | TotalBandwidth: 2140.0
# Episode 637 | TotalReward: 47.869364153439044 | TotalBandwidth: 2240.0
# Episode 638 | TotalReward: 32.20116115001558 | TotalBandwidth: 2640.0
# Episode 639 | TotalReward: 39.45547526455019 | TotalBandwidth: 2340.0
# Episode 640 | TotalReward: 36.42215129399585 | TotalBandwidth: 2680.0
# Episode 641 | TotalReward: 45.99093637566127 | TotalBandwidth: 2060.0
# Episode 642 | TotalReward: 47.87231507936497 | TotalBandwidth: 2340.0
# Episode 643 | TotalReward: 47.869364153439044 | TotalBandwidth: 2200.0
# Episode 644 | TotalReward: 47.87231507936497 | TotalBandwidth: 2360.0
# Episode 645 | TotalReward: 47.869364153439044 | TotalBandwidth: 2240.0
# Episode 646 | TotalReward: 43.6309410052909 | TotalBandwidth: 2220.0
# Episode 647 | TotalReward: 39.84295978835976 | TotalBandwidth: 2280.0
# Episode 648 | TotalReward: 43.989221560846474 | TotalBandwidth: 2140.0
# Episode 649 | TotalReward: 39.45842619047612 | TotalBandwidth: 1980.0
# Episode 650 | TotalReward: 35.959866269841264 | TotalBandwidth: 2300.0
# Episode 651 | TotalReward: 47.87231507936497 | TotalBandwidth: 2320.0
# Episode 652 | TotalReward: 47.87231507936497 | TotalBandwidth: 2240.0
# Episode 653 | TotalReward: 39.84295978835976 | TotalBandwidth: 2420.0
# Episode 654 | TotalReward: 47.87231507936497 | TotalBandwidth: 1860.0
# Episode 655 | TotalReward: 40.32896441798938 | TotalBandwidth: 2400.0
# Episode 656 | TotalReward: 47.869364153439044 | TotalBandwidth: 2380.0
# Episode 657 | TotalReward: 47.87231507936497 | TotalBandwidth: 2300.0
# Episode 658 | TotalReward: 40.72096071428568 | TotalBandwidth: 2400.0
# Episode 659 | TotalReward: 47.87231507936497 | TotalBandwidth: 2280.0
# Episode 660 | TotalReward: 47.87231507936497 | TotalBandwidth: 2220.0
# Episode 661 | TotalReward: 47.87231507936497 | TotalBandwidth: 2240.0
# Episode 662 | TotalReward: 47.87231507936497 | TotalBandwidth: 2160.0
# Episode 663 | TotalReward: 47.87231507936497 | TotalBandwidth: 2240.0
# Episode 664 | TotalReward: 46.08838306878295 | TotalBandwidth: 2520.0
# Episode 665 | TotalReward: 48.75031600529089 | TotalBandwidth: 2160.0
# Episode 666 | TotalReward: 47.87231507936497 | TotalBandwidth: 2400.0
# Episode 667 | TotalReward: 48.75031600529089 | TotalBandwidth: 2060.0
# Episode 668 | TotalReward: 47.87231507936497 | TotalBandwidth: 2140.0
# Episode 669 | TotalReward: 47.87231507936497 | TotalBandwidth: 2240.0
# Episode 670 | TotalReward: 45.99093637566127 | TotalBandwidth: 2140.0
# Episode 671 | TotalReward: 47.87231507936497 | TotalBandwidth: 2160.0
# Episode 672 | TotalReward: 39.84295978835976 | TotalBandwidth: 2220.0
# Episode 673 | TotalReward: 39.84295978835976 | TotalBandwidth: 2220.0
# Episode 674 | TotalReward: 47.87231507936497 | TotalBandwidth: 2200.0
# Episode 675 | TotalReward: 47.73882632275121 | TotalBandwidth: 2620.0
# Episode 676 | TotalReward: 48.75031600529089 | TotalBandwidth: 2280.0
# Episode 677 | TotalReward: 47.87231507936497 | TotalBandwidth: 2120.0
# Episode 678 | TotalReward: 47.87231507936497 | TotalBandwidth: 2120.0
# Episode 679 | TotalReward: 27.69671419234361 | TotalBandwidth: 2480.0
# Episode 680 | TotalReward: 40.30570247841823 | TotalBandwidth: 2580.0
# Episode 681 | TotalReward: 47.87231507936497 | TotalBandwidth: 1880.0
# ...
# Episode 819 | TotalReward: 47.87231507936497 | TotalBandwidth: 2200.0
# Episode 820 | TotalReward: 40.902886811391156 | TotalBandwidth: 2320.0
# Episode 821 | TotalReward: 43.423141005290915 | TotalBandwidth: 2140.0
# Episode 822 | TotalReward: 47.87231507936497 | TotalBandwidth: 2120.0
# Episode 823 | TotalReward: 40.20807711640208 | TotalBandwidth: 2300.0
# Episode 824 | TotalReward: 40.206410449735415 | TotalBandwidth: 2300.0
# Episode 825 | TotalReward: 40.206410449735415 | TotalBandwidth: 2300.0
# Episode 826 | TotalReward: 31.87212063492063 | TotalBandwidth: 2540.0
# Episode 827 | TotalReward: 39.02523082010579 | TotalBandwidth: 2640.0
# Episode 828 | TotalReward: 39.03010582010578 | TotalBandwidth: 2520.0
# Episode 829 | TotalReward: 40.206410449735415 | TotalBandwidth: 2280.0
# Episode 830 | TotalReward: 39.03010582010578 | TotalBandwidth: 2380.0
# Episode 831 | TotalReward: 39.028439153439116 | TotalBandwidth: 2460.0
# Episode 832 | TotalReward: 39.028439153439116 | TotalBandwidth: 2460.0
# Episode 833 | TotalReward: 42.9203604497354 | TotalBandwidth: 2320.0
# Episode 834 | TotalReward: 39.028439153439116 | TotalBandwidth: 2440.0
# Episode 835 | TotalReward: 41.08441137566134 | TotalBandwidth: 2340.0
# Episode 836 | TotalReward: 47.04509100529089 | TotalBandwidth: 2200.0
# Episode 837 | TotalReward: 40.206410449735415 | TotalBandwidth: 2200.0
# Episode 838 | TotalReward: 41.08441137566134 | TotalBandwidth: 2140.0
# Episode 839 | TotalReward: 39.369080820105765 | TotalBandwidth: 2200.0
# Episode 840 | TotalReward: 42.92202711640207 | TotalBandwidth: 2300.0
# Episode 841 | TotalReward: 44.974666005290956 | TotalBandwidth: 2360.0
# Episode 842 | TotalReward: 39.028439153439116 | TotalBandwidth: 2380.0
# Episode 843 | TotalReward: 39.02227973314926 | TotalBandwidth: 2660.0
# Episode 844 | TotalReward: 49.17179656084645 | TotalBandwidth: 2140.0
# Episode 845 | TotalReward: 39.03010582010578 | TotalBandwidth: 2540.0
# Episode 846 | TotalReward: 44.061302116402004 | TotalBandwidth: 2260.0
# Episode 847 | TotalReward: 39.020035449735424 | TotalBandwidth: 2700.0
# Episode 848 | TotalReward: 44.059592857142746 | TotalBandwidth: 2040.0
# Episode 849 | TotalReward: 44.059592857142746 | TotalBandwidth: 2320.0
# Episode 850 | TotalReward: 47.826113888888784 | TotalBandwidth: 2440.0
# Episode 851 | TotalReward: 39.705642857142756 | TotalBandwidth: 2620.0
# Episode 852 | TotalReward: 44.974666005290956 | TotalBandwidth: 2320.0
# Episode 853 | TotalReward: 43.9792234126983 | TotalBandwidth: 2120.0
# Episode 854 | TotalReward: 42.9203604497354 | TotalBandwidth: 2220.0
# Episode 855 | TotalReward: 39.36031044973538 | TotalBandwidth: 2180.0
# Episode 856 | TotalReward: 45.76652711640201 | TotalBandwidth: 2080.0
# Episode 857 | TotalReward: 43.70888822751312 | TotalBandwidth: 2400.0
# Episode 858 | TotalReward: 44.66120119047606 | TotalBandwidth: 2280.0
# Episode 859 | TotalReward: 44.056641931216824 | TotalBandwidth: 2300.0
# Episode 860 | TotalReward: 43.10122248677237 | TotalBandwidth: 2220.0
# Episode 861 | TotalReward: 38.252909523809436 | TotalBandwidth: 2300.0
# Episode 862 | TotalReward: 41.921966931216815 | TotalBandwidth: 2440.0
# Episode 863 | TotalReward: 42.9203604497354 | TotalBandwidth: 2100.0
# Episode 864 | TotalReward: 45.00857248677236 | TotalBandwidth: 2120.0
# Episode 865 | TotalReward: 44.66120119047606 | TotalBandwidth: 2160.0
# Episode 866 | TotalReward: 45.76652711640201 | TotalBandwidth: 2100.0
# Episode 867 | TotalReward: 38.924905820105714 | TotalBandwidth: 2060.0
# Episode 868 | TotalReward: 43.23143915343904 | TotalBandwidth: 2380.0
# Episode 869 | TotalReward: 39.64681230158718 | TotalBandwidth: 2160.0
# Episode 870 | TotalReward: 44.66120119047606 | TotalBandwidth: 2180.0
# Episode 871 | TotalReward: 39.63931230158718 | TotalBandwidth: 2420.0
# Episode 872 | TotalReward: 38.924905820105714 | TotalBandwidth: 2120.0
# Episode 873 | TotalReward: 39.62728849206337 | TotalBandwidth: 3140.0
# Episode 874 | TotalReward: 35.715692857142756 | TotalBandwidth: 2300.0
# Episode 875 | TotalReward: 44.995853042327916 | TotalBandwidth: 2940.0
# Episode 876 | TotalReward: 48.75031600529089 | TotalBandwidth: 2180.0
# Episode 877 | TotalReward: 49.25280304232794 | TotalBandwidth: 2340.0
# Episode 878 | TotalReward: 50.87702156084645 | TotalBandwidth: 2100.0
# Episode 879 | TotalReward: 46.68564768170415 | TotalBandwidth: 2560.0
# Episode 880 | TotalReward: 45.52558008911156 | TotalBandwidth: 2820.0
# Episode 881 | TotalReward: 47.98142139376207 | TotalBandwidth: 2800.0
# Episode 882 | TotalReward: 47.87231507936497 | TotalBandwidth: 2180.0
# Episode 883 | TotalReward: 47.87231507936497 | TotalBandwidth: 2080.0
# Episode 884 | TotalReward: 43.165260449735385 | TotalBandwidth: 2220.0
# Episode 885 | TotalReward: 49.69129401280969 | TotalBandwidth: 2460.0
# Episode 886 | TotalReward: 49.68834308688377 | TotalBandwidth: 2480.0
# Episode 887 | TotalReward: 48.83895304232794 | TotalBandwidth: 2240.0
# Episode 888 | TotalReward: 47.07856233548837 | TotalBandwidth: 2940.0
# Episode 889 | TotalReward: 46.18521560846554 | TotalBandwidth: 2320.0
# Episode 890 | TotalReward: 46.09570052910041 | TotalBandwidth: 2020.0
# Episode 891 | TotalReward: 46.52976970899463 | TotalBandwidth: 2000.0
# Episode 892 | TotalReward: 44.8795965608465 | TotalBandwidth: 2240.0
# Episode 893 | TotalReward: 45.76357619047608 | TotalBandwidth: 2100.0
# Episode 894 | TotalReward: 44.57720119047609 | TotalBandwidth: 2500.0
# Episode 895 | TotalReward: 45.76357619047608 | TotalBandwidth: 2100.0
# Episode 896 | TotalReward: 45.53432711640197 | TotalBandwidth: 2220.0
# Episode 897 | TotalReward: 45.53432711640197 | TotalBandwidth: 2180.0
# Episode 898 | TotalReward: 38.52288650793644 | TotalBandwidth: 2860.0
# Episode 899 | TotalReward: 45.76652711640201 | TotalBandwidth: 2140.0
# Episode 900 | TotalReward: 45.76652711640201 | TotalBandwidth: 1840.0
# Episode 901 | TotalReward: 45.53432711640197 | TotalBandwidth: 2160.0
# Episode 902 | TotalReward: 32.41002933027007 | TotalBandwidth: 2840.0
# Episode 903 | TotalReward: 45.53432711640197 | TotalBandwidth: 2180.0
# Episode 904 | TotalReward: 44.3537030423279 | TotalBandwidth: 2100.0
# Episode 905 | TotalReward: 33.359168783068775 | TotalBandwidth: 2120.0
# Episode 906 | TotalReward: 45.53432711640197 | TotalBandwidth: 2140.0
# Episode 907 | TotalReward: 45.76357619047608 | TotalBandwidth: 2260.0
# Episode 908 | TotalReward: 45.53432711640197 | TotalBandwidth: 2120.0
# Episode 909 | TotalReward: 45.53432711640197 | TotalBandwidth: 2180.0
# Episode 910 | TotalReward: 37.27927526455018 | TotalBandwidth: 2340.0
# Episode 911 | TotalReward: 40.03866610275681 | TotalBandwidth: 2640.0
# Episode 912 | TotalReward: 45.76652711640201 | TotalBandwidth: 2200.0
# Episode 913 | TotalReward: 45.342601058200984 | TotalBandwidth: 2760.0
# Episode 914 | TotalReward: 44.347158465608324 | TotalBandwidth: 2740.0
# Episode 915 | TotalReward: 45.34522010582003 | TotalBandwidth: 2600.0
# Episode 916 | TotalReward: 46.52976970899463 | TotalBandwidth: 2240.0
# Episode 917 | TotalReward: 46.52976970899463 | TotalBandwidth: 2280.0
# Episode 918 | TotalReward: 46.52976970899463 | TotalBandwidth: 2120.0
# Episode 919 | TotalReward: 46.52976970899463 | TotalBandwidth: 2200.0
# Episode 920 | TotalReward: 45.53432711640197 | TotalBandwidth: 2180.0
# Episode 921 | TotalReward: 46.52976970899463 | TotalBandwidth: 2240.0
# Episode 922 | TotalReward: 46.52976970899463 | TotalBandwidth: 2200.0
# Episode 923 | TotalReward: 46.52976970899463 | TotalBandwidth: 2060.0
# Episode 924 | TotalReward: 46.52976970899463 | TotalBandwidth: 2340.0
# Episode 925 | TotalReward: 46.52976970899463 | TotalBandwidth: 2240.0
# Episode 926 | TotalReward: 46.52976970899463 | TotalBandwidth: 2120.0
# Episode 927 | TotalReward: 41.06303174603169 | TotalBandwidth: 2500.0
# Episode 928 | TotalReward: 46.52976970899463 | TotalBandwidth: 2300.0
# Episode 929 | TotalReward: 48.505946418396306 | TotalBandwidth: 2280.0
# Episode 930 | TotalReward: 45.34492248677241 | TotalBandwidth: 2660.0
# Episode 931 | TotalReward: 50.87702156084645 | TotalBandwidth: 2060.0
# Episode 932 | TotalReward: 46.52976970899463 | TotalBandwidth: 2180.0
# Episode 933 | TotalReward: 48.83895304232794 | TotalBandwidth: 2220.0
# Episode 934 | TotalReward: 46.52976970899463 | TotalBandwidth: 2100.0
# Episode 935 | TotalReward: 46.52976970899463 | TotalBandwidth: 2240.0
# Episode 936 | TotalReward: 46.52976970899463 | TotalBandwidth: 2300.0
# Episode 937 | TotalReward: 45.531376190476045 | TotalBandwidth: 2240.0
# Episode 938 | TotalReward: 45.76652711640201 | TotalBandwidth: 2060.0
# Episode 939 | TotalReward: 45.76652711640201 | TotalBandwidth: 2100.0
# Episode 940 | TotalReward: 46.52976970899463 | TotalBandwidth: 2160.0
# Episode 941 | TotalReward: 46.52976970899463 | TotalBandwidth: 2200.0
# Episode 942 | TotalReward: 46.52976970899463 | TotalBandwidth: 2280.0
# Episode 943 | TotalReward: 45.53432711640197 | TotalBandwidth: 2040.0
# Episode 944 | TotalReward: 38.377778968253836 | TotalBandwidth: 2500.0
# Episode 945 | TotalReward: 45.34522010582003 | TotalBandwidth: 2620.0
# Episode 946 | TotalReward: 44.34682658730145 | TotalBandwidth: 2540.0
# Episode 947 | TotalReward: 44.87612433862428 | TotalBandwidth: 2540.0
# Episode 948 | TotalReward: 44.887013227513165 | TotalBandwidth: 2120.0
# Episode 949 | TotalReward: 44.887013227513165 | TotalBandwidth: 2020.0
# Episode 950 | TotalReward: 46.52976970899463 | TotalBandwidth: 2080.0
# Episode 951 | TotalReward: 46.52976970899463 | TotalBandwidth: 2320.0
# Episode 952 | TotalReward: 46.52976970899463 | TotalBandwidth: 2280.0
# Episode 953 | TotalReward: 39.29354378306873 | TotalBandwidth: 2400.0
# Episode 954 | TotalReward: 46.52976970899463 | TotalBandwidth: 2180.0
# Episode 955 | TotalReward: 46.52976970899463 | TotalBandwidth: 2220.0
# Episode 956 | TotalReward: 44.87572751322745 | TotalBandwidth: 2340.0
# Episode 957 | TotalReward: 41.431717592592456 | TotalBandwidth: 3420.0
# Episode 958 | TotalReward: 44.65337526455012 | TotalBandwidth: 2280.0
# Episode 959 | TotalReward: 29.622178404344123 | TotalBandwidth: 2280.0
# Episode 960 | TotalReward: 45.531376190476045 | TotalBandwidth: 2400.0
# Episode 961 | TotalReward: 40.516987301587164 | TotalBandwidth: 2080.0
# Episode 962 | TotalReward: 44.159632671957546 | TotalBandwidth: 2160.0
# Episode 963 | TotalReward: 40.814610449735326 | TotalBandwidth: 2420.0
# Episode 964 | TotalReward: 41.57285026455013 | TotalBandwidth: 2240.0
# Episode 965 | TotalReward: 38.41313082010567 | TotalBandwidth: 2540.0
# Episode 966 | TotalReward: 45.90056878306865 | TotalBandwidth: 3000.0
# Episode 967 | TotalReward: 42.04490859788346 | TotalBandwidth: 3040.0
# Episode 968 | TotalReward: 42.04490859788346 | TotalBandwidth: 2900.0
# Episode 969 | TotalReward: 47.07016507936493 | TotalBandwidth: 2640.0
# Episode 970 | TotalReward: 42.068159523809385 | TotalBandwidth: 2580.0
# Episode 971 | TotalReward: 48.05769100529093 | TotalBandwidth: 3060.0
# Episode 972 | TotalReward: 47.06513082010568 | TotalBandwidth: 2580.0
# Episode 973 | TotalReward: 46.70199563492049 | TotalBandwidth: 2140.0
# Episode 974 | TotalReward: 42.05699193121679 | TotalBandwidth: 2340.0
# Episode 975 | TotalReward: 36.73287896825382 | TotalBandwidth: 2280.0
# Episode 976 | TotalReward: 47.0680817460316 | TotalBandwidth: 2400.0
# Episode 977 | TotalReward: 42.05369285714272 | TotalBandwidth: 2400.0
# Episode 978 | TotalReward: 47.0680817460316 | TotalBandwidth: 2400.0
# Episode 979 | TotalReward: 47.0680817460316 | TotalBandwidth: 2380.0
# Episode 980 | TotalReward: 43.43043637566122 | TotalBandwidth: 2300.0
# Episode 981 | TotalReward: 47.0680817460316 | TotalBandwidth: 2440.0
# Episode 982 | TotalReward: 44.159632671957546 | TotalBandwidth: 2100.0
# Episode 983 | TotalReward: 47.06513082010568 | TotalBandwidth: 2520.0
# Episode 984 | TotalReward: 47.0743317460316 | TotalBandwidth: 2280.0
# Episode 985 | TotalReward: 42.053241931216796 | TotalBandwidth: 2280.0
# Episode 986 | TotalReward: 47.19087989417975 | TotalBandwidth: 2240.0
# Episode 987 | TotalReward: 47.51273822751308 | TotalBandwidth: 2120.0
# Episode 988 | TotalReward: 47.07522460317446 | TotalBandwidth: 2220.0
# Episode 989 | TotalReward: 48.06781005290998 | TotalBandwidth: 2320.0
# Episode 990 | TotalReward: 40.39031507936496 | TotalBandwidth: 2380.0
# Episode 991 | TotalReward: 46.34444285714272 | TotalBandwidth: 2180.0
# Episode 992 | TotalReward: 51.78045701058191 | TotalBandwidth: 2340.0
# Episode 993 | TotalReward: 42.776598677248614 | TotalBandwidth: 2300.0
# Episode 994 | TotalReward: 42.776598677248614 | TotalBandwidth: 2200.0
# Episode 995 | TotalReward: 46.41424404761899 | TotalBandwidth: 2340.0
# Episode 996 | TotalReward: 48.06352433862426 | TotalBandwidth: 2320.0
# Episode 997 | TotalReward: 48.070667195767115 | TotalBandwidth: 2420.0
# Episode 998 | TotalReward: 48.06566719576712 | TotalBandwidth: 2360.0
# Episode 999 | TotalReward: 48.48777804232796 | TotalBandwidth: 2220.0
# Cycle 0 | Action: 20.0 | Reward: -1 | TotalRewar: -1.0 | p_vio: 0.9444444444444444 | p_drop: 0.9161111111111111
# Cycle 1 | Action: 80.0 | Reward: 7.745023148148122 | TotalRewar: 6.745023148148122 | p_vio: 0.08694444444444445 | p_drop: 0.003611111111111111
# Cycle 2 | Action: 40.0 | Reward: 0.4292537037037041 | TotalRewar: 7.174276851851826 | p_vio: 0.0 | p_drop: 0.0
# Cycle 3 | Action: 40.0 | Reward: 0.025402777777777778 | TotalRewar: 7.199679629629604 | p_vio: 0.0 | p_drop: 0.0
# Cycle 4 | Action: 40.0 | Reward: 0.35731851851851865 | TotalRewar: 7.556998148148123 | p_vio: 0.0 | p_drop: 0.0
# Cycle 5 | Action: 40.0 | Reward: -1 | TotalRewar: 6.556998148148123 | p_vio: 0.6655555555555556 | p_drop: 0.5055555555555555
# Cycle 6 | Action: 100.0 | Reward: 5.185119444444437 | TotalRewar: 11.74211759259256 | p_vio: 0.058055555555555555 | p_drop: 0.002777777777777778
# Cycle 7 | Action: 40.0 | Reward: -1 | TotalRewar: 10.74211759259256 | p_vio: 0.9433333333333334 | p_drop: 0.9155555555555556
# Cycle 8 | Action: 100.0 | Reward: 6.162642592592579 | TotalRewar: 16.90476018518514 | p_vio: 0.06888888888888889 | p_drop: 0.0030555555555555557
# Cycle 9 | Action: 40.0 | Reward: -1 | TotalRewar: 15.90476018518514 | p_vio: 0.8905555555555555 | p_drop: 0.8363888888888888
# Cycle 10 | Action: 100.0 | Reward: 7.798538888888873 | TotalRewar: 23.703299074074014 | p_vio: 0.08777777777777777 | p_drop: 0.004722222222222222
# Cycle 11 | Action: 40.0 | Reward: -1 | TotalRewar: 22.703299074074014 | p_vio: 0.9330555555555555 | p_drop: 0.8988888888888888
# Cycle 12 | Action: 120.0 | Reward: 7.68216944444444 | TotalRewar: 30.385468518518454 | p_vio: 0.08833333333333333 | p_drop: 0.004166666666666667
# Cycle 13 | Action: 80.0 | Reward: -1 | TotalRewar: 29.385468518518454 | p_vio: 0.6736111111111112 | p_drop: 0.5116666666666667
# Cycle 14 | Action: 120.0 | Reward: 8.09226388888887 | TotalRewar: 37.47773240740732 | p_vio: 0.09027777777777778 | p_drop: 0.0033333333333333335
# Cycle 15 | Action: 40.0 | Reward: -1 | TotalRewar: 36.47773240740732 | p_vio: 0.9588888888888889 | p_drop: 0.9383333333333334
# Cycle 16 | Action: 140.0 | Reward: 5.216086375661375 | TotalRewar: 41.6938187830687 | p_vio: 0.058888888888888886 | p_drop: 0.0030555555555555557
# Cycle 17 | Action: 100.0 | Reward: -1 | TotalRewar: 40.6938187830687 | p_vio: 0.945 | p_drop: 0.9163888888888889
# Cycle 18 | Action: 200.0 | Reward: 5.044154629629622 | TotalRewar: 45.737973412698324 | p_vio: 0.056666666666666664 | p_drop: 0.0022222222222222222
# Cycle 19 | Action: 20.0 | Reward: -1 | TotalRewar: 44.737973412698324 | p_vio: 0.9791666666666666 | p_drop: 0.9686111111111111
# Cycle 20 | Action: 200.0 | Reward: -1 | TotalRewar: 43.737973412698324 | p_vio: 1.0 | p_drop: 0.20583333333333334
# Cycle 21 | Action: 200.0 | Reward: 3.578276851851865 | TotalRewar: 47.31625026455019 | p_vio: 0.03833333333333333 | p_drop: 0.0
# Cycle 22 | Action: 120.0 | Reward: -1 | TotalRewar: 46.31625026455019 | p_vio: 0.6483333333333333 | p_drop: 0.4666666666666667
# Cycle 23 | Action: 160.0 | Reward: 2.191930555555554 | TotalRewar: 48.50818082010574 | p_vio: 0.024444444444444446 | p_drop: 0.0011111111111111111
# Episode 1000 | TotalReward: 48.50818082010574 | TotalBandwidth: 2180.0
# Training finished. Saved model to dqn_policy_final.pth
