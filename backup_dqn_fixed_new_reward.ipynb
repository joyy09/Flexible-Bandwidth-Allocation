# %%
import numpy as np
import random
from collections import deque
import torch
import torch.nn as nn
import torch.optim as optim
import math
import time
import matplotlib.pyplot as plt

# %%
# -------------------------
# Environment & traffic params
# -------------------------
T_p = 1             # time quantum (seconds)
L = 300             # packet/bit size placeholder (not used explicitly)
Q_max = 60          # threshold for high queue
Q_threshold = 40   # threshold for low queue
W_max = 500         # max bandwidth (units treated as service capacity per second)
cycles = 24         # number of cycles per episode (hours)
second_in_hour = 3600            # seconds per cycle (1 hour)
episodes = 1000      # reduce for faster runs; set to 1000 for full run
hours_in_day = 24   # hours in a day

# action levels (same cardinality as original)
W_levels = np.linspace(0, W_max, 26)  # 26 bandwidth choices (0, 20, 40, ... if W_max=500)
mean_arrival_rates = np.array([80, 60, 40, 30, 40, 50, 70, 100, 75, 70, 80, 90, 100, 90, 100, 120, 110, 160, 170, 180, 200, 160, 130, 90,])

# %%
# -------------------------
# Poisson traffic generator (data generation for visualization)
# -------------------------

def generate_poisson_traffic(λ, duration):
    R = np.random.rand(int(λ * duration * 2))
    IAT = -np.log(1 - R) / λ
    arrivals = np.cumsum(IAT)
    return arrivals[arrivals <= duration]

bits_arrival_for_day = []

for hour, λ in enumerate(mean_arrival_rates):
    bits_arrival_for_hour = generate_poisson_traffic(λ, second_in_hour)
    bits_arrival_for_hour += hour * second_in_hour
    bits_arrival_for_day.extend(bits_arrival_for_hour)

time_bins = np.arange(0, hours_in_day*second_in_hour + 1, 1)
bits_arrival_counts, _ = np.histogram(bits_arrival_for_day, bins=time_bins)

# %%
def discretize_state(Qlength):
    # Return 0,1,2 depending on Qlength bins (low/medium/high).
    if Qlength <= Q_threshold:
        return 0
    elif Qlength < Q_max:
        return 1
    else:
        return 2

def encode_state(cycle_idx, Qlength):
    # Return a float32 state vector for the NN: [cycle_norm, one_hot_state0, one_hot_state1, one_hot_state2]
    s = discretize_state(Qlength)
    one_hot = np.zeros(3, dtype=np.float32)
    one_hot[s] = 1.0
    cycle_norm = np.array([cycle_idx / (cycles - 1)], dtype=np.float32)
    return np.concatenate([cycle_norm, one_hot], axis=0)  # shape (4,)

def update_queue(Q, arrivals, u):
    new_packets = arrivals
    Q_new = Q + ((new_packets - u) * T_p / L)
    return max(0, min(Q_new, Q_max + 1))

state_size = 4
action_size = len(W_levels)

# -------------------------
# The per-cycle environment rollout (exact dynamics & reward)
# -------------------------
def env_rollout_one_cycle(cycle_idx, action_bandwidth, Qlength_init):
    Qlength = float(Qlength_init)
    Q_history = []

    for t in range(second_in_hour):
        arrivals_this_sec = int(bits_arrival_counts[cycle_idx * second_in_hour + t])
        Qlength = update_queue(Qlength, arrivals_this_sec, action_bandwidth)
        Q_history.append(Qlength)

    Q_mean = np.mean(Q_history)
    p_violation = np.mean(np.array(Q_history) >= Q_threshold)
    p_drop = np.mean(np.array(Q_history) >= Q_max)

    if p_violation <= 0.1 and p_drop <= 0.01:
        if action_bandwidth == 0:
            reward = Q_mean
        else:
            reward = Q_mean + ( mean_arrival_rates[cycle_idx] / (action_bandwidth))
            print(f"Cycle {cycle_idx} | Action: {action_bandwidth} | Reward: {reward} | Qlength: {Q_mean}")
    elif (p_violation > 0.1 and p_drop <= 0.01) or (p_violation <= 0.1 and p_drop > 0.01):
        reward = 0
    else:
        reward = -1

    return reward, float(Q_history[-1]), p_violation, p_drop

# %%
# -------------------------
# DQN (PyTorch)
# -------------------------
class DQNNet(nn.Module):
    def __init__(self, state_size, action_size):
        super(DQNNet, self).__init__()
        self.fc1 = nn.Linear(state_size, 64)
        self.fc2 = nn.Linear(64, 64)
        self.fc3 = nn.Linear(64, action_size)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return self.fc3(x)

# -------------------------
# Agent
# -------------------------
class DQNAgent:
    def __init__(self, state_size, action_size, lr=1e-3, gamma=0.99, epsilon=1.0, epsilon_min=0.01, epsilon_decay=0.995, memory_size=20000, batch_size=64, target_update_steps=1000):
        self.state_size = state_size
        self.action_size = action_size
        self.gamma = gamma
        self.epsilon = epsilon
        self.epsilon_min = epsilon_min
        self.epsilon_decay = epsilon_decay
        self.batch_size = batch_size
        self.memory = deque(maxlen=memory_size)
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

        self.policy_net = DQNNet(state_size, action_size).to(self.device)
        self.target_net = DQNNet(state_size, action_size).to(self.device)
        self.target_net.load_state_dict(self.policy_net.state_dict())
        self.target_net.eval()

        self.optimizer = optim.Adam(self.policy_net.parameters(), lr=lr)
        self.loss_fn = nn.SmoothL1Loss()  # Huber (less sensitive to outliers)

        self.learn_step_counter = 0
        self.target_update_steps = target_update_steps

    def act(self, state_vec):
        # state_vec: numpy array shape (state_size,)
        if np.random.rand() < self.epsilon:
            return random.randrange(self.action_size)
        s = torch.from_numpy(state_vec).float().unsqueeze(0).to(self.device)  # [1, state_size]
        with torch.no_grad():
            q = self.policy_net(s)
            return int(q.argmax(dim=1).item())

    def remember(self, s, a, r, s2, done):
        self.memory.append((s, a, r, s2, done))

    def sample_batch(self):
        batch = random.sample(self.memory, self.batch_size)
        states, actions, rewards, next_states, dones = zip(*batch)
        states = torch.FloatTensor(np.stack(states)).to(self.device)
        actions = torch.LongTensor(actions).unsqueeze(1).to(self.device)
        rewards = torch.FloatTensor(rewards).unsqueeze(1).to(self.device)
        next_states = torch.FloatTensor(np.stack(next_states)).to(self.device)
        dones = torch.FloatTensor(dones).unsqueeze(1).to(self.device)
        return states, actions, rewards, next_states, dones

    def learn(self):
        if len(self.memory) < max(self.batch_size, 1000):
            return

        states, actions, rewards, next_states, dones = self.sample_batch()

        # current Q(s,a)
        q_values = self.policy_net(states).gather(1, actions)  # [batch,1]

        # target: r + gamma * max_a' Q_target(s', a')
        with torch.no_grad():
            next_q_values = self.target_net(next_states).max(1)[0].unsqueeze(1)  # [batch,1]

        target_q = rewards + self.gamma * next_q_values * (1 - dones)

        loss = self.loss_fn(q_values, target_q)

        self.optimizer.zero_grad()
        loss.backward()
        # gradient clipping for stability
        torch.nn.utils.clip_grad_norm_(self.policy_net.parameters(), 10.0)
        self.optimizer.step()

        # increment step counter and update target network if needed
        self.learn_step_counter += 1
        if self.learn_step_counter % self.target_update_steps == 0:
            self.target_net.load_state_dict(self.policy_net.state_dict())

# %%
# -------------------------
# Main training loop
# -------------------------
def train():
    agent = DQNAgent(state_size=state_size, action_size=action_size, lr=1e-3, gamma=0.99, epsilon=1.0, epsilon_min=0.01, epsilon_decay=0.9995, memory_size=20000, batch_size=64, target_update_steps=2000)

    rewards_history = []
    bandwidth_history = []

    for ep in range(1, episodes + 1):
        Qlength = 0.0
        total_bandwidth_episode = 0.0
        total_reward_episode = 0.0

        for cycle_idx in range(cycles):
            state_vec = encode_state(cycle_idx, Qlength)
            action_idx = agent.act(state_vec)
            action_bandwidth = float(W_levels[action_idx])

            reward, Qlength_next, p_viloation, p_drop = env_rollout_one_cycle(cycle_idx, action_bandwidth, Qlength)

            next_state_vec = encode_state(min(cycle_idx + 1, cycles - 1), Qlength_next)
            done = 1.0 if cycle_idx == (cycles - 1) else 0.0

            # store transition (states are small vectors)
            agent.remember(state_vec, action_idx, reward, next_state_vec, done)

            # learn from memory
            agent.learn()

            # update for next cycle
            Qlength = Qlength_next
            total_reward_episode += reward
            total_bandwidth_episode += action_bandwidth

            if ep == 1000:
                print(f"Cycle {cycle_idx} | Action: {action_bandwidth} | Reward: {reward} | TotalReward: {total_reward_episode} | p_vio: {p_viloation} | p_drop: {p_drop} | Qlength: {Qlength}")

        rewards_history.append(total_reward_episode)
        bandwidth_history.append(total_bandwidth_episode)
        agent.epsilon = max(agent.epsilon_min, agent.epsilon * agent.epsilon_decay)

        
        print(f"Episode {ep} | TotalReward: {total_reward_episode} | TotalBandwidth: {total_bandwidth_episode}")

    # final save
    torch.save(agent.policy_net.state_dict(), "dqn_policy_final.pth")
    print("Training finished. Saved model to dqn_policy_final.pth")
    return rewards_history, bandwidth_history

if __name__ == "__main__":
    reward_history, bandwidth_history = train()
    plt.plot(reward_history)
    plt.show()
# Out:
# Cycle 2 | Action: 340.0 | Reward: 0.6246090958605666 | Qlength: 0.5069620370370371
# Cycle 3 | Action: 480.0 | Reward: 0.0625 | Qlength: 0.0
# Cycle 4 | Action: 60.0 | Reward: 0.6666740740740741 | Qlength: 7.4074074074074075e-06
# Cycle 5 | Action: 60.0 | Reward: 0.8345953703703705 | Qlength: 0.001262037037037037
# Cycle 6 | Action: 480.0 | Reward: 0.14583333333333334 | Qlength: 0.0
# Cycle 7 | Action: 260.0 | Reward: 0.38461538461538464 | Qlength: 0.0
# Cycle 8 | Action: 140.0 | Reward: 0.5357142857142857 | Qlength: 0.0
# Cycle 9 | Action: 320.0 | Reward: 0.21875 | Qlength: 0.0
# Cycle 10 | Action: 340.0 | Reward: 0.23529411764705882 | Qlength: 0.0
# Cycle 12 | Action: 120.0 | Reward: 8.626459259259244 | Qlength: 7.79312592592591
# Cycle 13 | Action: 100.0 | Reward: 0.9040888888888889 | Qlength: 0.0040888888888888884
# Cycle 14 | Action: 360.0 | Reward: 0.2777777777777778 | Qlength: 0.0
# Cycle 15 | Action: 440.0 | Reward: 0.2727272727272727 | Qlength: 0.0
# Cycle 17 | Action: 400.0 | Reward: 1.0304185185185184 | Qlength: 0.6304185185185183
# Cycle 18 | Action: 300.0 | Reward: 0.5666666666666667 | Qlength: 0.0
# Cycle 19 | Action: 420.0 | Reward: 0.42857142857142855 | Qlength: 0.0
# Cycle 20 | Action: 400.0 | Reward: 0.5 | Qlength: 0.0
# Cycle 23 | Action: 180.0 | Reward: 2.1985314814814805 | Qlength: 1.6985314814814807
# Episode 1 | TotalReward: 12.513826955506353 | TotalBandwidth: 5600.0
# Cycle 1 | Action: 300.0 | Reward: 0.8337194444444442 | Qlength: 0.6337194444444443
# Cycle 2 | Action: 100.0 | Reward: 0.4 | Qlength: 0.0
# Cycle 3 | Action: 100.0 | Reward: 0.3 | Qlength: 0.0
# Cycle 4 | Action: 480.0 | Reward: 0.08333333333333333 | Qlength: 0.0
# Cycle 5 | Action: 400.0 | Reward: 0.125 | Qlength: 0.0
# Cycle 6 | Action: 140.0 | Reward: 0.5 | Qlength: 0.0
# Cycle 7 | Action: 280.0 | Reward: 0.35714285714285715 | Qlength: 0.0
# Cycle 9 | Action: 160.0 | Reward: 2.183176851851851 | Qlength: 1.7456768518518506
# Cycle 10 | Action: 240.0 | Reward: 0.3333333333333333 | Qlength: 0.0
# Cycle 11 | Action: 360.0 | Reward: 0.25 | Qlength: 0.0
# Cycle 12 | Action: 300.0 | Reward: 0.3333333333333333 | Qlength: 0.0
# Cycle 13 | Action: 380.0 | Reward: 0.23684210526315788 | Qlength: 0.0
# Cycle 15 | Action: 260.0 | Reward: 1.5654884615384623 | Qlength: 1.1039500000000007
# Cycle 16 | Action: 120.0 | Reward: 0.9223185185185184 | Qlength: 0.0056518518518518515
# Cycle 17 | Action: 420.0 | Reward: 0.38095238095238093 | Qlength: 0.0
# Cycle 18 | Action: 220.0 | Reward: 0.7727272727272727 | Qlength: 0.0
# Cycle 20 | Action: 500.0 | Reward: 0.9118953703703706 | Qlength: 0.5118953703703706
# Cycle 21 | Action: 420.0 | Reward: 0.38095238095238093 | Qlength: 0.0
# Cycle 23 | Action: 320.0 | Reward: 0.9421777777777779 | Qlength: 0.6609277777777779
# Episode 2 | TotalReward: 6.812393421539473 | TotalBandwidth: 5740.0
# Cycle 0 | Action: 320.0 | Reward: 0.25 | Qlength: 0.0
# Cycle 1 | Action: 280.0 | Reward: 0.21428571428571427 | Qlength: 0.0
# Cycle 2 | Action: 440.0 | Reward: 0.09090909090909091 | Qlength: 0.0
# Cycle 3 | Action: 300.0 | Reward: 0.1 | Qlength: 0.0
# Cycle 5 | Action: 500.0 | Reward: 0.43691388888888893 | Qlength: 0.33691388888888896
# Cycle 6 | Action: 280.0 | Reward: 0.25 | Qlength: 0.0
# Cycle 7 | Action: 380.0 | Reward: 0.2631578947368421 | Qlength: 0.0
# Cycle 8 | Action: 420.0 | Reward: 0.17857142857142858 | Qlength: 0.0
# Cycle 9 | Action: 440.0 | Reward: 0.1590909090909091 | Qlength: 0.0
# Cycle 10 | Action: 460.0 | Reward: 0.17391304347826086 | Qlength: 0.0
# Cycle 11 | Action: 120.0 | Reward: 0.7500064814814815 | Qlength: 6.481481481481482e-06
# Cycle 12 | Action: 240.0 | Reward: 0.4166666666666667 | Qlength: 0.0
# Cycle 13 | Action: 260.0 | Reward: 0.34615384615384615 | Qlength: 0.0
# Cycle 15 | Action: 260.0 | Reward: 1.5654884615384623 | Qlength: 1.1039500000000007
# Cycle 16 | Action: 320.0 | Reward: 0.34375 | Qlength: 0.0
# Cycle 17 | Action: 320.0 | Reward: 0.5 | Qlength: 0.0
# Cycle 18 | Action: 420.0 | Reward: 0.40476190476190477 | Qlength: 0.0
# Cycle 19 | Action: 340.0 | Reward: 0.5294117647058824 | Qlength: 0.0
# Cycle 20 | Action: 420.0 | Reward: 0.47619047619047616 | Qlength: 0.0
# Episode 3 | TotalReward: 2.449271571459855 | TotalBandwidth: 6700.0
# Cycle 0 | Action: 460.0 | Reward: 0.17391304347826086 | Qlength: 0.0
# Cycle 1 | Action: 420.0 | Reward: 0.14285714285714285 | Qlength: 0.0
# Cycle 2 | Action: 240.0 | Reward: 0.16666666666666666 | Qlength: 0.0
# Cycle 3 | Action: 300.0 | Reward: 0.1 | Qlength: 0.0
# Cycle 4 | Action: 280.0 | Reward: 0.14285714285714285 | Qlength: 0.0
# Cycle 5 | Action: 480.0 | Reward: 0.10416666666666667 | Qlength: 0.0
# Cycle 6 | Action: 500.0 | Reward: 0.14 | Qlength: 0.0
# Cycle 7 | Action: 500.0 | Reward: 0.2 | Qlength: 0.0
# Cycle 9 | Action: 460.0 | Reward: 0.5449840982286634 | Qlength: 0.3928101851851852
# Cycle 10 | Action: 480.0 | Reward: 0.16666666666666666 | Qlength: 0.0
# Cycle 11 | Action: 280.0 | Reward: 0.32142857142857145 | Qlength: 0.0
# Cycle 13 | Action: 140.0 | Reward: 3.816599735449738 | Qlength: 3.1737425925925953
# Cycle 14 | Action: 400.0 | Reward: 0.25 | Qlength: 0.0
# Cycle 15 | Action: 500.0 | Reward: 0.24 | Qlength: 0.0
# Cycle 18 | Action: 320.0 | Reward: 1.5532925925925922 | Qlength: 1.0220425925925922
# Cycle 19 | Action: 320.0 | Reward: 0.5625 | Qlength: 0.0
# Cycle 20 | Action: 300.0 | Reward: 0.6666666666666666 | Qlength: 0.0
# Cycle 21 | Action: 380.0 | Reward: 0.42105263157894735 | Qlength: 0.0
# Cycle 22 | Action: 220.0 | Reward: 0.5909090909090909 | Qlength: 0.0
# Cycle 23 | Action: 500.0 | Reward: 0.18 | Qlength: 0.0
# Episode 4 | TotalReward: 6.4845607160468175 | TotalBandwidth: 7680.0
# Cycle 0 | Action: 100.0 | Reward: 0.8001666666666667 | Qlength: 0.00016666666666666666
# Cycle 1 | Action: 160.0 | Reward: 0.375 | Qlength: 0.0
# Cycle 2 | Action: 180.0 | Reward: 0.2222222222222222 | Qlength: 0.0
# Cycle 3 | Action: 100.0 | Reward: 0.3 | Qlength: 0.0
# Cycle 4 | Action: 460.0 | Reward: 0.08695652173913043 | Qlength: 0.0
# Cycle 5 | Action: 380.0 | Reward: 0.13157894736842105 | Qlength: 0.0
# Cycle 6 | Action: 400.0 | Reward: 0.175 | Qlength: 0.0
# Cycle 7 | Action: 140.0 | Reward: 0.7142857142857143 | Qlength: 0.0
# Cycle 8 | Action: 200.0 | Reward: 0.375 | Qlength: 0.0
# Cycle 9 | Action: 300.0 | Reward: 0.23333333333333334 | Qlength: 0.0
# Cycle 10 | Action: 340.0 | Reward: 0.23529411764705882 | Qlength: 0.0
# Cycle 11 | Action: 240.0 | Reward: 0.375 | Qlength: 0.0
# Cycle 12 | Action: 180.0 | Reward: 0.5555555555555556 | Qlength: 0.0
# Cycle 13 | Action: 240.0 | Reward: 0.375 | Qlength: 0.0
# Cycle 14 | Action: 240.0 | Reward: 0.4166666666666667 | Qlength: 0.0
# Cycle 15 | Action: 240.0 | Reward: 0.5 | Qlength: 0.0
# Cycle 16 | Action: 440.0 | Reward: 0.25 | Qlength: 0.0
# Cycle 18 | Action: 440.0 | Reward: 0.9492043771043772 | Qlength: 0.5628407407407409
# Cycle 19 | Action: 440.0 | Reward: 0.4090909090909091 | Qlength: 0.0
# Cycle 21 | Action: 200.0 | Reward: 4.661619444444446 | Qlength: 3.8616194444444454
# Cycle 22 | Action: 140.0 | Reward: 0.9350862433862435 | Qlength: 0.006514814814814814
# Cycle 23 | Action: 280.0 | Reward: 0.32142857142857145 | Qlength: 0.0
# Episode 5 | TotalReward: 11.397489290939316 | TotalBandwidth: 6080.0
# Cycle 0 | Action: 400.0 | Reward: 0.2 | Qlength: 0.0
# Cycle 1 | Action: 480.0 | Reward: 0.125 | Qlength: 0.0
# Cycle 2 | Action: 440.0 | Reward: 0.09090909090909091 | Qlength: 0.0
# Cycle 3 | Action: 260.0 | Reward: 0.11538461538461539 | Qlength: 0.0
# Cycle 4 | Action: 380.0 | Reward: 0.10526315789473684 | Qlength: 0.0
# Cycle 5 | Action: 380.0 | Reward: 0.13157894736842105 | Qlength: 0.0
# Cycle 6 | Action: 140.0 | Reward: 0.5 | Qlength: 0.0
# Cycle 8 | Action: 440.0 | Reward: 0.5860730639730641 | Qlength: 0.41561851851851866
# Cycle 9 | Action: 220.0 | Reward: 0.3181818181818182 | Qlength: 0.0
# Cycle 10 | Action: 300.0 | Reward: 0.26666666666666666 | Qlength: 0.0
# Cycle 11 | Action: 100.0 | Reward: 0.9036796296296297 | Qlength: 0.0036796296296296295
# Cycle 12 | Action: 200.0 | Reward: 0.5 | Qlength: 0.0
# Cycle 13 | Action: 420.0 | Reward: 0.21428571428571427 | Qlength: 0.0
# Cycle 16 | Action: 160.0 | Reward: 3.7697731481481482 | Qlength: 3.0822731481481482
# Cycle 17 | Action: 360.0 | Reward: 0.4444444444444444 | Qlength: 0.0
# Cycle 19 | Action: 240.0 | Reward: 3.330772222222224 | Qlength: 2.580772222222224
# Cycle 21 | Action: 500.0 | Reward: 0.7637166666666668 | Qlength: 0.44371666666666676
# Cycle 22 | Action: 380.0 | Reward: 0.34210526315789475 | Qlength: 0.0
# Cycle 23 | Action: 500.0 | Reward: 0.18 | Qlength: 0.0
# Episode 6 | TotalReward: 7.887834448933137 | TotalBandwidth: 6720.0
# Cycle 2 | Action: 180.0 | Reward: 1.3151462962962968 | Qlength: 1.0929240740740747
# Cycle 3 | Action: 300.0 | Reward: 0.1 | Qlength: 0.0
# Cycle 4 | Action: 40.0 | Reward: 1.3957749999999995 | Qlength: 0.3957749999999996
# Cycle 5 | Action: 220.0 | Reward: 0.22727272727272727 | Qlength: 0.0
# Cycle 6 | Action: 460.0 | Reward: 0.15217391304347827 | Qlength: 0.0
# Cycle 7 | Action: 380.0 | Reward: 0.2631578947368421 | Qlength: 0.0
# Cycle 8 | Action: 240.0 | Reward: 0.3125 | Qlength: 0.0
# Cycle 11 | Action: 360.0 | Reward: 0.8138722222222222 | Qlength: 0.5638722222222222
# Cycle 16 | Action: 220.0 | Reward: 1.7569518518518477 | Qlength: 1.2569518518518477
# Cycle 18 | Action: 240.0 | Reward: 2.9082990740740735 | Qlength: 2.19996574074074
# Cycle 21 | Action: 300.0 | Reward: 1.6188157407407409 | Qlength: 1.0854824074074074
# Episode 7 | TotalReward: -1.136035279761772 | TotalBandwidth: 3580.0
# Cycle 0 | Action: 80.0 | Reward: 1.3242416666666668 | Qlength: 0.32424166666666676
# Cycle 1 | Action: 340.0 | Reward: 0.17647058823529413 | Qlength: 0.0
# Cycle 2 | Action: 80.0 | Reward: 0.5 | Qlength: 0.0
# Cycle 3 | Action: 260.0 | Reward: 0.11538461538461539 | Qlength: 0.0
# Cycle 4 | Action: 240.0 | Reward: 0.16666666666666666 | Qlength: 0.0
# Cycle 6 | Action: 420.0 | Reward: 0.6010990740740741 | Qlength: 0.43443240740740746
# Cycle 8 | Action: 500.0 | Reward: 0.5059472222222221 | Qlength: 0.35594722222222214
# Cycle 9 | Action: 500.0 | Reward: 0.14 | Qlength: 0.0
# Cycle 10 | Action: 80.0 | Reward: 2.108782407407408 | Qlength: 1.108782407407408
# Cycle 11 | Action: 260.0 | Reward: 0.3468769943019943 | Qlength: 0.0007231481481481498
# Cycle 12 | Action: 200.0 | Reward: 0.5 | Qlength: 0.0
# Cycle 13 | Action: 260.0 | Reward: 0.34615384615384615 | Qlength: 0.0
# Cycle 14 | Action: 320.0 | Reward: 0.3125 | Qlength: 0.0
# Cycle 15 | Action: 220.0 | Reward: 0.5454545454545454 | Qlength: 0.0
# Cycle 16 | Action: 340.0 | Reward: 0.3235294117647059 | Qlength: 0.0
# Cycle 17 | Action: 320.0 | Reward: 0.5 | Qlength: 0.0
# Cycle 19 | Action: 200.0 | Reward: 8.65597407407406 | Qlength: 7.755974074074059
# Cycle 21 | Action: 440.0 | Reward: 0.9038493265993267 | Qlength: 0.5402129629629631
# Cycle 22 | Action: 260.0 | Reward: 0.5 | Qlength: 0.0
# Cycle 23 | Action: 480.0 | Reward: 0.1875 | Qlength: 0.0
# Episode 8 | TotalReward: 14.760430439005424 | TotalBandwidth: 6080.0
# Cycle 0 | Action: 320.0 | Reward: 0.25 | Qlength: 0.0
# Cycle 1 | Action: 120.0 | Reward: 0.5 | Qlength: 0.0
# Cycle 2 | Action: 340.0 | Reward: 0.11764705882352941 | Qlength: 0.0
# Cycle 4 | Action: 440.0 | Reward: 0.4703220538720537 | Qlength: 0.37941296296296284
# Cycle 5 | Action: 80.0 | Reward: 0.625 | Qlength: 0.0
# Cycle 6 | Action: 240.0 | Reward: 0.2916666666666667 | Qlength: 0.0
# Cycle 7 | Action: 480.0 | Reward: 0.20833333333333334 | Qlength: 0.0
# Cycle 8 | Action: 120.0 | Reward: 0.625 | Qlength: 0.0
# Cycle 9 | Action: 240.0 | Reward: 0.2916666666666667 | Qlength: 0.0
# Cycle 10 | Action: 120.0 | Reward: 0.6666666666666666 | Qlength: 0.0
# Cycle 12 | Action: 360.0 | Reward: 0.8671999999999997 | Qlength: 0.589422222222222
# Cycle 13 | Action: 140.0 | Reward: 0.6428571428571429 | Qlength: 0.0
# Cycle 14 | Action: 440.0 | Reward: 0.22727272727272727 | Qlength: 0.0
# Cycle 15 | Action: 360.0 | Reward: 0.3333333333333333 | Qlength: 0.0
# Cycle 16 | Action: 140.0 | Reward: 0.7857559523809524 | Qlength: 4.166666666666667e-05
# Cycle 18 | Action: 220.0 | Reward: 3.8460569023569056 | Qlength: 3.0733296296296326
# Cycle 19 | Action: 280.0 | Reward: 0.6428571428571429 | Qlength: 0.0
# Cycle 20 | Action: 460.0 | Reward: 0.43478260869565216 | Qlength: 0.0
# Episode 9 | TotalReward: 5.826418255782771 | TotalBandwidth: 5240.0
# Cycle 0 | Action: 160.0 | Reward: 0.5 | Qlength: 0.0
# Cycle 1 | Action: 200.0 | Reward: 0.3 | Qlength: 0.0
# Cycle 2 | Action: 160.0 | Reward: 0.25 | Qlength: 0.0
# Cycle 3 | Action: 400.0 | Reward: 0.075 | Qlength: 0.0
# Cycle 4 | Action: 240.0 | Reward: 0.16666666666666666 | Qlength: 0.0
# Cycle 5 | Action: 80.0 | Reward: 0.625 | Qlength: 0.0
# Cycle 6 | Action: 320.0 | Reward: 0.21875 | Qlength: 0.0
# Cycle 9 | Action: 300.0 | Reward: 0.9079888888888887 | Qlength: 0.6746555555555553
# Cycle 10 | Action: 180.0 | Reward: 0.4444444444444444 | Qlength: 0.0
# Cycle 13 | Action: 480.0 | Reward: 0.5784694444444444 | Qlength: 0.39096944444444437
# Cycle 14 | Action: 500.0 | Reward: 0.2 | Qlength: 0.0
# Cycle 16 | Action: 160.0 | Reward: 3.7697731481481482 | Qlength: 3.0822731481481482
# Cycle 17 | Action: 220.0 | Reward: 0.7272727272727273 | Qlength: 0.0
# Cycle 18 | Action: 260.0 | Reward: 0.6538461538461539 | Qlength: 0.0
# Cycle 19 | Action: 260.0 | Reward: 0.6923076923076923 | Qlength: 0.0
# Cycle 22 | Action: 220.0 | Reward: 2.326330387205387 | Qlength: 1.7354212962962958
# Episode 10 | TotalReward: 4.435849553224553 | TotalBandwidth: 4380.0
# Cycle 0 | Action: 440.0 | Reward: 0.18181818181818182 | Qlength: 0.0
# Cycle 1 | Action: 480.0 | Reward: 0.125 | Qlength: 0.0
# Cycle 3 | Action: 480.0 | Reward: 0.3984379629629629 | Qlength: 0.3359379629629629
# Cycle 4 | Action: 240.0 | Reward: 0.16666666666666666 | Qlength: 0.0
# Cycle 5 | Action: 460.0 | Reward: 0.10869565217391304 | Qlength: 0.0
# Cycle 6 | Action: 380.0 | Reward: 0.18421052631578946 | Qlength: 0.0
# Cycle 7 | Action: 340.0 | Reward: 0.29411764705882354 | Qlength: 0.0
# Cycle 8 | Action: 500.0 | Reward: 0.15 | Qlength: 0.0
# Cycle 10 | Action: 220.0 | Reward: 1.4647206228956233 | Qlength: 1.1010842592592596
# Cycle 11 | Action: 220.0 | Reward: 0.4090909090909091 | Qlength: 0.0
# Cycle 12 | Action: 200.0 | Reward: 0.5 | Qlength: 0.0
# Cycle 13 | Action: 100.0 | Reward: 0.9040888888888889 | Qlength: 0.0040888888888888884
# Cycle 14 | Action: 140.0 | Reward: 0.714290343915344 | Qlength: 4.6296296296296296e-06
# Cycle 17 | Action: 460.0 | Reward: 0.34782608695652173 | Qlength: 0.0
# Cycle 22 | Action: 260.0 | Reward: 1.6948351851851855 | Qlength: 1.1948351851851855
# Cycle 23 | Action: 300.0 | Reward: 0.3 | Qlength: 0.0
# Episode 11 | TotalReward: 0.9437986739288098 | TotalBandwidth: 5820.0
# Cycle 0 | Action: 400.0 | Reward: 0.2 | Qlength: 0.0
# Cycle 1 | Action: 100.0 | Reward: 0.6 | Qlength: 0.0
# Cycle 2 | Action: 480.0 | Reward: 0.08333333333333333 | Qlength: 0.0
# Cycle 3 | Action: 300.0 | Reward: 0.1 | Qlength: 0.0
# Cycle 4 | Action: 380.0 | Reward: 0.10526315789473684 | Qlength: 0.0
# Cycle 5 | Action: 460.0 | Reward: 0.10869565217391304 | Qlength: 0.0
# Cycle 6 | Action: 120.0 | Reward: 0.5833333333333334 | Qlength: 0.0
# Cycle 7 | Action: 500.0 | Reward: 0.2 | Qlength: 0.0
# Cycle 8 | Action: 380.0 | Reward: 0.19736842105263158 | Qlength: 0.0
# Cycle 10 | Action: 260.0 | Reward: 1.1618478632478628 | Qlength: 0.8541555555555551
# Cycle 11 | Action: 440.0 | Reward: 0.20454545454545456 | Qlength: 0.0
# Cycle 12 | Action: 200.0 | Reward: 0.5 | Qlength: 0.0
# Cycle 14 | Action: 460.0 | Reward: 0.6351320450885669 | Qlength: 0.4177407407407408
# Cycle 15 | Action: 440.0 | Reward: 0.2727272727272727 | Qlength: 0.0
# Cycle 16 | Action: 380.0 | Reward: 0.2894736842105263 | Qlength: 0.0
# Cycle 17 | Action: 320.0 | Reward: 0.5 | Qlength: 0.0
# Cycle 18 | Action: 200.0 | Reward: 0.8501824074074074 | Qlength: 0.00018240740740740742
# Cycle 22 | Action: 480.0 | Reward: 0.706786111111111 | Qlength: 0.4359527777777777
# Cycle 23 | Action: 160.0 | Reward: 0.5625 | Qlength: 0.0
# Episode 12 | TotalReward: 2.86118873612615 | TotalBandwidth: 6560.0
# Cycle 0 | Action: 360.0 | Reward: 0.2222222222222222 | Qlength: 0.0
# Cycle 1 | Action: 200.0 | Reward: 0.3 | Qlength: 0.0
# Cycle 2 | Action: 120.0 | Reward: 0.3333333333333333 | Qlength: 0.0
# Cycle 3 | Action: 400.0 | Reward: 0.075 | Qlength: 0.0
# Cycle 4 | Action: 460.0 | Reward: 0.08695652173913043 | Qlength: 0.0
# Cycle 5 | Action: 380.0 | Reward: 0.13157894736842105 | Qlength: 0.0
# Cycle 6 | Action: 420.0 | Reward: 0.16666666666666666 | Qlength: 0.0
# Cycle 7 | Action: 300.0 | Reward: 0.3333333333333333 | Qlength: 0.0
# Cycle 8 | Action: 440.0 | Reward: 0.17045454545454544 | Qlength: 0.0
# Cycle 9 | Action: 500.0 | Reward: 0.14 | Qlength: 0.0
# Cycle 11 | Action: 360.0 | Reward: 0.8138722222222222 | Qlength: 0.5638722222222222
# Cycle 14 | Action: 320.0 | Reward: 0.9975111111111108 | Qlength: 0.6850111111111108
# Cycle 15 | Action: 240.0 | Reward: 0.5 | Qlength: 0.0
# Cycle 16 | Action: 220.0 | Reward: 0.5 | Qlength: 0.0
# Cycle 17 | Action: 280.0 | Reward: 0.5714285714285714 | Qlength: 0.0
# Cycle 18 | Action: 260.0 | Reward: 0.6538461538461539 | Qlength: 0.0
# Cycle 20 | Action: 480.0 | Reward: 0.9657638888888889 | Qlength: 0.5490972222222221
# Cycle 21 | Action: 260.0 | Reward: 0.6153846153846154 | Qlength: 0.0
# Cycle 22 | Action: 400.0 | Reward: 0.325 | Qlength: 0.0
# Cycle 23 | Action: 240.0 | Reward: 0.375 | Qlength: 0.0
# Episode 13 | TotalReward: 4.277352132999216 | TotalBandwidth: 6960.0
# Cycle 0 | Action: 100.0 | Reward: 0.8001666666666667 | Qlength: 0.00016666666666666666
# Cycle 1 | Action: 460.0 | Reward: 0.13043478260869565 | Qlength: 0.0
# Cycle 2 | Action: 40.0 | Reward: 1.523186111111111 | Qlength: 0.523186111111111
# Cycle 3 | Action: 280.0 | Reward: 0.10714285714285714 | Qlength: 0.0
# Cycle 4 | Action: 180.0 | Reward: 0.2222222222222222 | Qlength: 0.0
# Cycle 5 | Action: 380.0 | Reward: 0.13157894736842105 | Qlength: 0.0
# Cycle 6 | Action: 100.0 | Reward: 0.7000092592592592 | Qlength: 9.259259259259259e-06
# Cycle 7 | Action: 360.0 | Reward: 0.2777777777777778 | Qlength: 0.0
# Cycle 9 | Action: 120.0 | Reward: 3.7513333333333367 | Qlength: 3.1680000000000033
# Cycle 10 | Action: 480.0 | Reward: 0.16666666666666666 | Qlength: 0.0
# Cycle 12 | Action: 300.0 | Reward: 1.1035629629629635 | Qlength: 0.7702296296296302
# Cycle 14 | Action: 440.0 | Reward: 0.6697912457912457 | Qlength: 0.4425185185185185
# Cycle 15 | Action: 340.0 | Reward: 0.35294117647058826 | Qlength: 0.0
# Cycle 16 | Action: 180.0 | Reward: 0.6111111111111112 | Qlength: 0.0
# Cycle 17 | Action: 480.0 | Reward: 0.3333333333333333 | Qlength: 0.0
# Cycle 18 | Action: 240.0 | Reward: 0.7083333333333334 | Qlength: 0.0
# Cycle 19 | Action: 320.0 | Reward: 0.5625 | Qlength: 0.0
# Cycle 20 | Action: 460.0 | Reward: 0.43478260869565216 | Qlength: 0.0
# Cycle 21 | Action: 300.0 | Reward: 0.5333333333333333 | Qlength: 0.0
# Cycle 23 | Action: 220.0 | Reward: 1.5805288720538724 | Qlength: 1.1714379629629632
# Episode 14 | TotalReward: 10.700736601242447 | TotalBandwidth: 6080.0
# Cycle 0 | Action: 380.0 | Reward: 0.21052631578947367 | Qlength: 0.0
# Cycle 2 | Action: 460.0 | Reward: 0.44730189210950083 | Qlength: 0.3603453703703704
# Cycle 3 | Action: 160.0 | Reward: 0.1875 | Qlength: 0.0
# Cycle 4 | Action: 140.0 | Reward: 0.2857142857142857 | Qlength: 0.0
# Cycle 5 | Action: 200.0 | Reward: 0.25 | Qlength: 0.0
# Cycle 6 | Action: 420.0 | Reward: 0.16666666666666666 | Qlength: 0.0
# Cycle 7 | Action: 240.0 | Reward: 0.4166666666666667 | Qlength: 0.0
# Cycle 8 | Action: 300.0 | Reward: 0.25 | Qlength: 0.0
# Cycle 9 | Action: 460.0 | Reward: 0.15217391304347827 | Qlength: 0.0
# Cycle 10 | Action: 80.0 | Reward: 2.108782407407408 | Qlength: 1.108782407407408
# Cycle 11 | Action: 140.0 | Reward: 0.6457339947089947 | Qlength: 0.0028768518518518574
# Cycle 12 | Action: 440.0 | Reward: 0.22727272727272727 | Qlength: 0.0
# Cycle 13 | Action: 280.0 | Reward: 0.32142857142857145 | Qlength: 0.0
# Cycle 15 | Action: 220.0 | Reward: 2.0928147306397307 | Qlength: 1.547360185185185
# Cycle 16 | Action: 300.0 | Reward: 0.36666666666666664 | Qlength: 0.0
# Cycle 17 | Action: 500.0 | Reward: 0.32 | Qlength: 0.0
# Cycle 18 | Action: 440.0 | Reward: 0.38636363636363635 | Qlength: 0.0
# Cycle 19 | Action: 380.0 | Reward: 0.47368421052631576 | Qlength: 0.0
# Cycle 20 | Action: 360.0 | Reward: 0.5555555555555556 | Qlength: 0.0
# Cycle 22 | Action: 340.0 | Reward: 1.1157566448801743 | Qlength: 0.7334037037037039
# Episode 15 | TotalReward: 6.980608885439853 | TotalBandwidth: 6380.0
# Cycle 1 | Action: 100.0 | Reward: 4.476726851851853 | Qlength: 3.876726851851853
# Cycle 3 | Action: 140.0 | Reward: 1.6209940476190472 | Qlength: 1.406708333333333
# Cycle 4 | Action: 40.0 | Reward: 1.3957749999999995 | Qlength: 0.3957749999999996
# Cycle 5 | Action: 400.0 | Reward: 0.125 | Qlength: 0.0
# Cycle 6 | Action: 300.0 | Reward: 0.23333333333333334 | Qlength: 0.0
# Cycle 8 | Action: 440.0 | Reward: 0.5860730639730641 | Qlength: 0.41561851851851866
# Cycle 9 | Action: 440.0 | Reward: 0.1590909090909091 | Qlength: 0.0
# Cycle 10 | Action: 100.0 | Reward: 0.8001990740740741 | Qlength: 0.0001990740740740741
# Cycle 12 | Action: 280.0 | Reward: 1.2143160052910054 | Qlength: 0.8571731481481483
# Cycle 13 | Action: 280.0 | Reward: 0.32142857142857145 | Qlength: 0.0
# Cycle 16 | Action: 420.0 | Reward: 0.7547492063492063 | Qlength: 0.4928444444444443
# Cycle 17 | Action: 260.0 | Reward: 0.6153846153846154 | Qlength: 0.0
# Cycle 18 | Action: 200.0 | Reward: 0.8501824074074074 | Qlength: 0.00018240740740740742
# Cycle 19 | Action: 200.0 | Reward: 0.9017314814814815 | Qlength: 0.0017314814814814818
# Cycle 20 | Action: 500.0 | Reward: 0.4 | Qlength: 0.0
# Cycle 22 | Action: 240.0 | Reward: 1.957580555555554 | Qlength: 1.4159138888888876
# Cycle 23 | Action: 460.0 | Reward: 0.1956521739130435 | Qlength: 0.0
# Episode 16 | TotalReward: 9.608217296753166 | TotalBandwidth: 5000.0
# Cycle 1 | Action: 80.0 | Reward: 8.615885185185148 | Qlength: 7.865885185185148
# Cycle 2 | Action: 320.0 | Reward: 0.125 | Qlength: 0.0
# Cycle 3 | Action: 260.0 | Reward: 0.11538461538461539 | Qlength: 0.0
# Cycle 4 | Action: 160.0 | Reward: 0.25 | Qlength: 0.0
# Cycle 5 | Action: 300.0 | Reward: 0.16666666666666666 | Qlength: 0.0
# Cycle 6 | Action: 340.0 | Reward: 0.20588235294117646 | Qlength: 0.0
# Cycle 7 | Action: 400.0 | Reward: 0.25 | Qlength: 0.0
# Cycle 9 | Action: 100.0 | Reward: 5.981186111111096 | Qlength: 5.281186111111096
# Cycle 11 | Action: 200.0 | Reward: 1.8368916666666666 | Qlength: 1.3868916666666666
# Cycle 12 | Action: 320.0 | Reward: 0.3125 | Qlength: 0.0
# Cycle 14 | Action: 260.0 | Reward: 1.3273107549857548 | Qlength: 0.9426953703703702
# Cycle 16 | Action: 140.0 | Reward: 5.921621693121688 | Qlength: 5.1359074074074025
# Cycle 17 | Action: 400.0 | Reward: 0.4 | Qlength: 0.0
# Cycle 18 | Action: 280.0 | Reward: 0.6071428571428571 | Qlength: 0.0
# Cycle 19 | Action: 360.0 | Reward: 0.5 | Qlength: 0.0
# Cycle 21 | Action: 200.0 | Reward: 4.661619444444446 | Qlength: 3.8616194444444454
# Cycle 22 | Action: 200.0 | Reward: 0.65 | Qlength: 0.0
# Cycle 23 | Action: 220.0 | Reward: 0.4090909090909091 | Qlength: 0.0
# Episode 17 | TotalReward: 26.336182256741022 | TotalBandwidth: 4920.0
# Cycle 0 | Action: 260.0 | Reward: 0.3076923076923077 | Qlength: 0.0
# Cycle 1 | Action: 280.0 | Reward: 0.21428571428571427 | Qlength: 0.0
# Cycle 2 | Action: 100.0 | Reward: 0.4 | Qlength: 0.0
# Cycle 3 | Action: 460.0 | Reward: 0.06521739130434782 | Qlength: 0.0
# Cycle 4 | Action: 220.0 | Reward: 0.18181818181818182 | Qlength: 0.0
# Cycle 5 | Action: 160.0 | Reward: 0.3125 | Qlength: 0.0
# Cycle 6 | Action: 160.0 | Reward: 0.4375 | Qlength: 0.0
# Cycle 8 | Action: 320.0 | Reward: 0.8571685185185185 | Qlength: 0.6227935185185185
# Cycle 9 | Action: 340.0 | Reward: 0.20588235294117646 | Qlength: 0.0
# Cycle 10 | Action: 240.0 | Reward: 0.3333333333333333 | Qlength: 0.0
# Cycle 11 | Action: 240.0 | Reward: 0.375 | Qlength: 0.0
# Cycle 13 | Action: 460.0 | Reward: 0.6083762479871176 | Qlength: 0.41272407407407413
# Cycle 14 | Action: 440.0 | Reward: 0.22727272727272727 | Qlength: 0.0
# Cycle 15 | Action: 120.0 | Reward: 1.4860231481481478 | Qlength: 0.4860231481481479
# Cycle 17 | Action: 420.0 | Reward: 0.9629699735449738 | Qlength: 0.5820175925925929
# Cycle 18 | Action: 260.0 | Reward: 0.6538461538461539 | Qlength: 0.0
# Cycle 21 | Action: 460.0 | Reward: 0.8517103462157811 | Qlength: 0.5038842592592594
# Cycle 22 | Action: 320.0 | Reward: 0.40625 | Qlength: 0.0
# Cycle 23 | Action: 300.0 | Reward: 0.3 | Qlength: 0.0
# Episode 18 | TotalReward: 4.186846396908481 | TotalBandwidth: 5900.0
# Cycle 0 | Action: 140.0 | Reward: 0.5714285714285714 | Qlength: 0.0
# Cycle 1 | Action: 200.0 | Reward: 0.3 | Qlength: 0.0
# Cycle 2 | Action: 440.0 | Reward: 0.09090909090909091 | Qlength: 0.0
# Cycle 3 | Action: 40.0 | Reward: 0.7503648148148148 | Qlength: 0.00036481481481481483
# Cycle 4 | Action: 260.0 | Reward: 0.15384615384615385 | Qlength: 0.0
# Cycle 5 | Action: 180.0 | Reward: 0.2777777777777778 | Qlength: 0.0
# Cycle 6 | Action: 500.0 | Reward: 0.14 | Qlength: 0.0
# Cycle 7 | Action: 140.0 | Reward: 0.7142857142857143 | Qlength: 0.0
# Cycle 8 | Action: 380.0 | Reward: 0.19736842105263158 | Qlength: 0.0
# Cycle 9 | Action: 480.0 | Reward: 0.14583333333333334 | Qlength: 0.0
# Cycle 10 | Action: 400.0 | Reward: 0.2 | Qlength: 0.0
# Cycle 11 | Action: 440.0 | Reward: 0.20454545454545456 | Qlength: 0.0
# Cycle 12 | Action: 160.0 | Reward: 0.625 | Qlength: 0.0
# Cycle 14 | Action: 120.0 | Reward: 8.382949074074048 | Qlength: 7.549615740740714
# Cycle 16 | Action: 460.0 | Reward: 0.6745461755233494 | Qlength: 0.4354157407407407
# Cycle 17 | Action: 320.0 | Reward: 0.5 | Qlength: 0.0
# Episode 19 | TotalReward: 5.92885458159094 | TotalBandwidth: 5020.0
# Cycle 0 | Action: 220.0 | Reward: 0.36363636363636365 | Qlength: 0.0
# Cycle 1 | Action: 340.0 | Reward: 0.17647058823529413 | Qlength: 0.0
# Cycle 2 | Action: 100.0 | Reward: 0.4 | Qlength: 0.0
# Cycle 3 | Action: 140.0 | Reward: 0.21428571428571427 | Qlength: 0.0
# Cycle 4 | Action: 60.0 | Reward: 0.6666740740740741 | Qlength: 7.4074074074074075e-06
# Cycle 5 | Action: 140.0 | Reward: 0.35714285714285715 | Qlength: 0.0
# Cycle 6 | Action: 400.0 | Reward: 0.175 | Qlength: 0.0
# Cycle 7 | Action: 400.0 | Reward: 0.25 | Qlength: 0.0
# Cycle 9 | Action: 400.0 | Reward: 0.6412305555555555 | Qlength: 0.46623055555555554
# Cycle 10 | Action: 460.0 | Reward: 0.17391304347826086 | Qlength: 0.0
# Cycle 11 | Action: 200.0 | Reward: 0.45 | Qlength: 0.0
# Cycle 12 | Action: 140.0 | Reward: 0.7142866402116402 | Qlength: 9.259259259259259e-07
# Cycle 13 | Action: 160.0 | Reward: 0.5625 | Qlength: 0.0
# Cycle 14 | Action: 180.0 | Reward: 0.5555555555555556 | Qlength: 0.0
# Cycle 15 | Action: 260.0 | Reward: 0.46153846153846156 | Qlength: 0.0
# Cycle 18 | Action: 200.0 | Reward: 5.947058333333332 | Qlength: 5.097058333333332
# Cycle 20 | Action: 340.0 | Reward: 1.6991991830065358 | Qlength: 1.1109638888888889
# Cycle 21 | Action: 340.0 | Reward: 0.47058823529411764 | Qlength: 0.0
# Cycle 23 | Action: 200.0 | Reward: 1.837222222222222 | Qlength: 1.3872222222222221
# Episode 20 | TotalReward: 11.116301827569984 | TotalBandwidth: 5000.0
# Cycle 0 | Action: 480.0 | Reward: 0.16666666666666666 | Qlength: 0.0
# Cycle 1 | Action: 220.0 | Reward: 0.2727272727272727 | Qlength: 0.0
# Cycle 2 | Action: 420.0 | Reward: 0.09523809523809523 | Qlength: 0.0
# Cycle 3 | Action: 500.0 | Reward: 0.06 | Qlength: 0.0
# Cycle 5 | Action: 440.0 | Reward: 0.5033391414141413 | Qlength: 0.3897027777777777
# Cycle 6 | Action: 460.0 | Reward: 0.15217391304347827 | Qlength: 0.0
# Cycle 7 | Action: 400.0 | Reward: 0.25 | Qlength: 0.0
# Cycle 8 | Action: 340.0 | Reward: 0.22058823529411764 | Qlength: 0.0
# Cycle 9 | Action: 460.0 | Reward: 0.15217391304347827 | Qlength: 0.0
# Cycle 11 | Action: 220.0 | Reward: 1.5821205387205393 | Qlength: 1.17302962962963
# Cycle 12 | Action: 480.0 | Reward: 0.20833333333333334 | Qlength: 0.0
# Cycle 13 | Action: 100.0 | Reward: 0.9040888888888889 | Qlength: 0.0040888888888888884
# Cycle 14 | Action: 340.0 | Reward: 0.29411764705882354 | Qlength: 0.0
# Cycle 15 | Action: 140.0 | Reward: 0.857894708994709 | Qlength: 0.000751851851851852
# Cycle 16 | Action: 140.0 | Reward: 0.7857559523809524 | Qlength: 4.166666666666667e-05
# Cycle 17 | Action: 400.0 | Reward: 0.4 | Qlength: 0.0
# Cycle 18 | Action: 460.0 | Reward: 0.3695652173913043 | Qlength: 0.0
# Cycle 21 | Action: 180.0 | Reward: 8.746644444444422 | Qlength: 7.857755555555533
# Cycle 22 | Action: 260.0 | Reward: 0.5 | Qlength: 0.0
# Cycle 23 | Action: 100.0 | Reward: 0.9037555555555555 | Qlength: 0.0037555555555555554
# Episode 21 | TotalReward: 13.42518352419578 | TotalBandwidth: 6740.0
# Cycle 1 | Action: 120.0 | Reward: 3.0720268518518536 | Qlength: 2.5720268518518536
# Cycle 2 | Action: 360.0 | Reward: 0.1111111111111111 | Qlength: 0.0
# Cycle 3 | Action: 440.0 | Reward: 0.06818181818181818 | Qlength: 0.0
# Cycle 5 | Action: 480.0 | Reward: 0.45707499999999995 | Qlength: 0.35290833333333327
# Cycle 6 | Action: 460.0 | Reward: 0.15217391304347827 | Qlength: 0.0
# Cycle 8 | Action: 440.0 | Reward: 0.5860730639730641 | Qlength: 0.41561851851851866
# Cycle 9 | Action: 120.0 | Reward: 0.5833333333333334 | Qlength: 0.0
# Cycle 10 | Action: 300.0 | Reward: 0.26666666666666666 | Qlength: 0.0
# Cycle 11 | Action: 420.0 | Reward: 0.21428571428571427 | Qlength: 0.0
# Cycle 12 | Action: 240.0 | Reward: 0.4166666666666667 | Qlength: 0.0
# Cycle 13 | Action: 360.0 | Reward: 0.25 | Qlength: 0.0
# Cycle 14 | Action: 460.0 | Reward: 0.21739130434782608 | Qlength: 0.0
# Cycle 15 | Action: 500.0 | Reward: 0.24 | Qlength: 0.0
# Cycle 16 | Action: 280.0 | Reward: 0.39285714285714285 | Qlength: 0.0
# Cycle 18 | Action: 220.0 | Reward: 3.8460569023569056 | Qlength: 3.0733296296296326
# Cycle 20 | Action: 380.0 | Reward: 1.386714863547758 | Qlength: 0.8603990740740738
# Cycle 21 | Action: 260.0 | Reward: 0.6153846153846154 | Qlength: 0.0
# Cycle 22 | Action: 240.0 | Reward: 0.5416666666666666 | Qlength: 0.0
# Cycle 23 | Action: 220.0 | Reward: 0.4090909090909091 | Qlength: 0.0
# Episode 22 | TotalReward: 8.82675654336553 | TotalBandwidth: 6620.0
# Cycle 1 | Action: 200.0 | Reward: 1.392449074074075 | Qlength: 1.0924490740740749
# Cycle 2 | Action: 80.0 | Reward: 0.5 | Qlength: 0.0
# Cycle 3 | Action: 500.0 | Reward: 0.06 | Qlength: 0.0
# Cycle 4 | Action: 360.0 | Reward: 0.1111111111111111 | Qlength: 0.0
# Cycle 5 | Action: 300.0 | Reward: 0.16666666666666666 | Qlength: 0.0
# Cycle 8 | Action: 420.0 | Reward: 0.6186992063492065 | Qlength: 0.4401277777777779
# Cycle 9 | Action: 280.0 | Reward: 0.25 | Qlength: 0.0
# Cycle 10 | Action: 260.0 | Reward: 0.3076923076923077 | Qlength: 0.0
# Cycle 11 | Action: 480.0 | Reward: 0.1875 | Qlength: 0.0
# Cycle 12 | Action: 500.0 | Reward: 0.2 | Qlength: 0.0
# Cycle 13 | Action: 140.0 | Reward: 0.6428571428571429 | Qlength: 0.0
# Cycle 14 | Action: 480.0 | Reward: 0.20833333333333334 | Qlength: 0.0
# Cycle 15 | Action: 460.0 | Reward: 0.2608695652173913 | Qlength: 0.0
# Cycle 17 | Action: 460.0 | Reward: 0.8519918276972626 | Qlength: 0.5041657407407408
# Cycle 22 | Action: 320.0 | Reward: 1.179610185185186 | Qlength: 0.7733601851851859
# Cycle 23 | Action: 280.0 | Reward: 0.32142857142857145 | Qlength: 0.0
# Episode 23 | TotalReward: -0.7407910083877454 | TotalBandwidth: 6200.0
# Cycle 0 | Action: 460.0 | Reward: 0.17391304347826086 | Qlength: 0.0
# Cycle 2 | Action: 440.0 | Reward: 0.4696164983164982 | Qlength: 0.3787074074074073
# Cycle 3 | Action: 500.0 | Reward: 0.06 | Qlength: 0.0
# Cycle 4 | Action: 80.0 | Reward: 0.5 | Qlength: 0.0
# Cycle 5 | Action: 260.0 | Reward: 0.19230769230769232 | Qlength: 0.0
# Cycle 6 | Action: 400.0 | Reward: 0.175 | Qlength: 0.0
# Cycle 7 | Action: 240.0 | Reward: 0.4166666666666667 | Qlength: 0.0
# Cycle 8 | Action: 200.0 | Reward: 0.375 | Qlength: 0.0
# Cycle 10 | Action: 500.0 | Reward: 0.5209750000000002 | Qlength: 0.3609750000000002
# Cycle 11 | Action: 280.0 | Reward: 0.32142857142857145 | Qlength: 0.0
# Cycle 12 | Action: 420.0 | Reward: 0.23809523809523808 | Qlength: 0.0
# Cycle 13 | Action: 500.0 | Reward: 0.18 | Qlength: 0.0
# Cycle 14 | Action: 200.0 | Reward: 0.5 | Qlength: 0.0
# Cycle 15 | Action: 400.0 | Reward: 0.3 | Qlength: 0.0
# Cycle 16 | Action: 480.0 | Reward: 0.22916666666666666 | Qlength: 0.0
# Cycle 17 | Action: 340.0 | Reward: 0.47058823529411764 | Qlength: 0.0
# Cycle 20 | Action: 360.0 | Reward: 1.5254990740740746 | Qlength: 0.969943518518519
# Cycle 21 | Action: 300.0 | Reward: 0.5333333333333333 | Qlength: 0.0
# Cycle 22 | Action: 300.0 | Reward: 0.43333333333333335 | Qlength: 0.0
# Cycle 23 | Action: 340.0 | Reward: 0.2647058823529412 | Qlength: 0.0
# Episode 24 | TotalReward: 3.8796292353473945 | TotalBandwidth: 7320.0
# Cycle 0 | Action: 460.0 | Reward: 0.17391304347826086 | Qlength: 0.0
# Cycle 1 | Action: 360.0 | Reward: 0.16666666666666666 | Qlength: 0.0
# Cycle 2 | Action: 100.0 | Reward: 0.4 | Qlength: 0.0
# Cycle 3 | Action: 140.0 | Reward: 0.21428571428571427 | Qlength: 0.0
# Cycle 4 | Action: 240.0 | Reward: 0.16666666666666666 | Qlength: 0.0
# Cycle 5 | Action: 180.0 | Reward: 0.2777777777777778 | Qlength: 0.0
# Cycle 6 | Action: 420.0 | Reward: 0.16666666666666666 | Qlength: 0.0
# Cycle 8 | Action: 260.0 | Reward: 1.1165874643874643 | Qlength: 0.8281259259259258
# Cycle 10 | Action: 100.0 | Reward: 8.630438888888861 | Qlength: 7.83043888888886
# Cycle 11 | Action: 340.0 | Reward: 0.2647058823529412 | Qlength: 0.0
# Cycle 13 | Action: 260.0 | Reward: 1.2617288461538458 | Qlength: 0.9155749999999996
# Cycle 14 | Action: 180.0 | Reward: 0.5555555555555556 | Qlength: 0.0
# Cycle 15 | Action: 360.0 | Reward: 0.3333333333333333 | Qlength: 0.0
# Cycle 16 | Action: 280.0 | Reward: 0.39285714285714285 | Qlength: 0.0
# Cycle 17 | Action: 160.0 | Reward: 4.200542592592592 | Qlength: 3.200542592592592
# Cycle 20 | Action: 400.0 | Reward: 1.2727953703703707 | Qlength: 0.7727953703703707
# Cycle 21 | Action: 200.0 | Reward: 0.8000194444444445 | Qlength: 1.9444444444444445e-05
# Episode 25 | TotalReward: 13.394541056478305 | TotalBandwidth: 4700.0
# Cycle 0 | Action: 240.0 | Reward: 0.3333333333333333 | Qlength: 0.0
# Cycle 1 | Action: 60.0 | Reward: 2.3884574074074054 | Qlength: 1.3884574074074054
# Cycle 2 | Action: 220.0 | Reward: 0.182428367003367 | Qlength: 0.0006101851851851795
# Cycle 4 | Action: 360.0 | Reward: 0.5876444444444444 | Qlength: 0.47653333333333325
# Cycle 6 | Action: 340.0 | Reward: 0.7714480936819172 | Qlength: 0.5655657407407408
# Cycle 8 | Action: 200.0 | Reward: 1.6089675925925928 | Qlength: 1.2339675925925928
# Cycle 9 | Action: 480.0 | Reward: 0.14583333333333334 | Qlength: 0.0
# Cycle 10 | Action: 160.0 | Reward: 0.5 | Qlength: 0.0
# Cycle 11 | Action: 360.0 | Reward: 0.25 | Qlength: 0.0
# Cycle 12 | Action: 180.0 | Reward: 0.5555555555555556 | Qlength: 0.0
# Cycle 13 | Action: 380.0 | Reward: 0.23684210526315788 | Qlength: 0.0
# Cycle 14 | Action: 280.0 | Reward: 0.35714285714285715 | Qlength: 0.0
# Cycle 15 | Action: 500.0 | Reward: 0.24 | Qlength: 0.0
# Cycle 16 | Action: 360.0 | Reward: 0.3055555555555556 | Qlength: 0.0
# Cycle 17 | Action: 160.0 | Reward: 4.200542592592592 | Qlength: 3.200542592592592
# Cycle 19 | Action: 200.0 | Reward: 8.65597407407406 | Qlength: 7.755974074074059
# Cycle 21 | Action: 300.0 | Reward: 1.6188157407407409 | Qlength: 1.0854824074074074
# Cycle 22 | Action: 280.0 | Reward: 0.4642857142857143 | Qlength: 0.0
# Cycle 23 | Action: 360.0 | Reward: 0.25 | Qlength: 0.0
# Episode 26 | TotalReward: 18.652826767006626 | TotalBandwidth: 5720.0
# Cycle 0 | Action: 100.0 | Reward: 0.8001666666666667 | Qlength: 0.00016666666666666666
# Cycle 1 | Action: 320.0 | Reward: 0.1875 | Qlength: 0.0
# Cycle 2 | Action: 180.0 | Reward: 0.2222222222222222 | Qlength: 0.0
# Cycle 3 | Action: 400.0 | Reward: 0.075 | Qlength: 0.0
# Cycle 4 | Action: 440.0 | Reward: 0.09090909090909091 | Qlength: 0.0
# Cycle 5 | Action: 100.0 | Reward: 0.5 | Qlength: 0.0
# Cycle 6 | Action: 480.0 | Reward: 0.14583333333333334 | Qlength: 0.0
# Cycle 7 | Action: 200.0 | Reward: 0.5 | Qlength: 0.0
# Cycle 8 | Action: 420.0 | Reward: 0.17857142857142858 | Qlength: 0.0
# Cycle 10 | Action: 360.0 | Reward: 0.7680268518518519 | Qlength: 0.5458046296296297
# Cycle 11 | Action: 420.0 | Reward: 0.21428571428571427 | Qlength: 0.0
# Cycle 12 | Action: 240.0 | Reward: 0.4166666666666667 | Qlength: 0.0
# Cycle 13 | Action: 120.0 | Reward: 0.7500074074074075 | Qlength: 7.407407407407407e-06
# Cycle 14 | Action: 500.0 | Reward: 0.2 | Qlength: 0.0
# Cycle 15 | Action: 280.0 | Reward: 0.42857142857142855 | Qlength: 0.0
# Cycle 17 | Action: 260.0 | Reward: 2.1158244301994307 | Qlength: 1.5004398148148153
# Cycle 18 | Action: 180.0 | Reward: 0.9532314814814815 | Qlength: 0.008787037037037038
# Cycle 19 | Action: 360.0 | Reward: 0.5 | Qlength: 0.0
# Cycle 20 | Action: 260.0 | Reward: 0.7692307692307693 | Qlength: 0.0
# Cycle 21 | Action: 460.0 | Reward: 0.34782608695652173 | Qlength: 0.0
# Cycle 22 | Action: 300.0 | Reward: 0.43333333333333335 | Qlength: 0.0
# Episode 27 | TotalReward: 7.597206911687348 | TotalBandwidth: 6480.0
# Cycle 0 | Action: 460.0 | Reward: 0.17391304347826086 | Qlength: 0.0
# Cycle 1 | Action: 400.0 | Reward: 0.15 | Qlength: 0.0
# Cycle 2 | Action: 400.0 | Reward: 0.1 | Qlength: 0.0
# Cycle 3 | Action: 460.0 | Reward: 0.06521739130434782 | Qlength: 0.0
# Cycle 4 | Action: 200.0 | Reward: 0.2 | Qlength: 0.0
# Cycle 5 | Action: 60.0 | Reward: 0.8345953703703705 | Qlength: 0.001262037037037037
# Cycle 6 | Action: 300.0 | Reward: 0.23333333333333334 | Qlength: 0.0
# Cycle 7 | Action: 260.0 | Reward: 0.38461538461538464 | Qlength: 0.0
# Cycle 8 | Action: 480.0 | Reward: 0.15625 | Qlength: 0.0
# Cycle 9 | Action: 360.0 | Reward: 0.19444444444444445 | Qlength: 0.0
# Cycle 10 | Action: 240.0 | Reward: 0.3333333333333333 | Qlength: 0.0
# Cycle 11 | Action: 300.0 | Reward: 0.3 | Qlength: 0.0
# Cycle 12 | Action: 480.0 | Reward: 0.20833333333333334 | Qlength: 0.0
# Cycle 13 | Action: 340.0 | Reward: 0.2647058823529412 | Qlength: 0.0
# Cycle 14 | Action: 240.0 | Reward: 0.4166666666666667 | Qlength: 0.0
# Cycle 15 | Action: 240.0 | Reward: 0.5 | Qlength: 0.0
# Cycle 16 | Action: 140.0 | Reward: 0.7857559523809524 | Qlength: 4.166666666666667e-05
# Cycle 19 | Action: 480.0 | Reward: 0.8835972222222223 | Qlength: 0.5085972222222223
# Cycle 20 | Action: 440.0 | Reward: 0.45454545454545453 | Qlength: 0.0
# Cycle 21 | Action: 420.0 | Reward: 0.38095238095238093 | Qlength: 0.0
# Cycle 23 | Action: 300.0 | Reward: 1.0242194444444441 | Qlength: 0.7242194444444441
# Episode 28 | TotalReward: 5.044478637777871 | TotalBandwidth: 7240.0
# Cycle 0 | Action: 260.0 | Reward: 0.3076923076923077 | Qlength: 0.0
# Cycle 2 | Action: 320.0 | Reward: 0.6685194444444447 | Qlength: 0.5435194444444447
# Cycle 3 | Action: 300.0 | Reward: 0.1 | Qlength: 0.0
# Cycle 4 | Action: 280.0 | Reward: 0.14285714285714285 | Qlength: 0.0
# Cycle 5 | Action: 200.0 | Reward: 0.25 | Qlength: 0.0
# Cycle 6 | Action: 440.0 | Reward: 0.1590909090909091 | Qlength: 0.0
# Cycle 7 | Action: 180.0 | Reward: 0.5555555555555556 | Qlength: 0.0
# Cycle 9 | Action: 200.0 | Reward: 1.5523351851851857 | Qlength: 1.2023351851851856
# Cycle 11 | Action: 300.0 | Reward: 1.0258953703703706 | Qlength: 0.7258953703703707
# Cycle 12 | Action: 380.0 | Reward: 0.2631578947368421 | Qlength: 0.0
# Cycle 13 | Action: 200.0 | Reward: 0.45 | Qlength: 0.0
# Cycle 14 | Action: 100.0 | Reward: 2.481957407407406 | Qlength: 1.481957407407406
# Cycle 15 | Action: 480.0 | Reward: 0.25023981481481483 | Qlength: 0.00023981481481481418
# Cycle 16 | Action: 120.0 | Reward: 0.9223185185185184 | Qlength: 0.0056518518518518515
# Cycle 17 | Action: 300.0 | Reward: 0.5333333333333333 | Qlength: 0.0
# Cycle 22 | Action: 420.0 | Reward: 0.8378080687830691 | Qlength: 0.5282842592592596
# Cycle 23 | Action: 500.0 | Reward: 0.18 | Qlength: 0.0
# Episode 29 | TotalReward: 3.680760952789901 | TotalBandwidth: 5380.0
# Cycle 0 | Action: 100.0 | Reward: 0.8001666666666667 | Qlength: 0.00016666666666666666
# Cycle 1 | Action: 460.0 | Reward: 0.13043478260869565 | Qlength: 0.0
# Cycle 2 | Action: 240.0 | Reward: 0.16666666666666666 | Qlength: 0.0
# Cycle 3 | Action: 260.0 | Reward: 0.11538461538461539 | Qlength: 0.0
# Cycle 4 | Action: 140.0 | Reward: 0.2857142857142857 | Qlength: 0.0
# Cycle 5 | Action: 500.0 | Reward: 0.1 | Qlength: 0.0
# Cycle 6 | Action: 220.0 | Reward: 0.3181818181818182 | Qlength: 0.0
# Cycle 7 | Action: 360.0 | Reward: 0.2777777777777778 | Qlength: 0.0
# Cycle 8 | Action: 340.0 | Reward: 0.22058823529411764 | Qlength: 0.0
# Cycle 9 | Action: 440.0 | Reward: 0.1590909090909091 | Qlength: 0.0
# Cycle 11 | Action: 320.0 | Reward: 0.9438888888888888 | Qlength: 0.6626388888888888
# Cycle 13 | Action: 160.0 | Reward: 2.8139425925925945 | Qlength: 2.2514425925925945
# Cycle 14 | Action: 300.0 | Reward: 0.3333333333333333 | Qlength: 0.0
# Cycle 15 | Action: 260.0 | Reward: 0.46153846153846156 | Qlength: 0.0
# Cycle 19 | Action: 420.0 | Reward: 1.0671019841269838 | Qlength: 0.6385305555555553
# Cycle 20 | Action: 420.0 | Reward: 0.47619047619047616 | Qlength: 0.0
# Cycle 21 | Action: 200.0 | Reward: 0.8000194444444445 | Qlength: 1.9444444444444445e-05
# Cycle 22 | Action: 340.0 | Reward: 0.38235294117647056 | Qlength: 0.0
# Cycle 23 | Action: 420.0 | Reward: 0.21428571428571427 | Qlength: 0.0
# Episode 30 | TotalReward: 5.06665959396292 | TotalBandwidth: 6160.0
# Cycle 0 | Action: 200.0 | Reward: 0.4 | Qlength: 0.0
# Cycle 2 | Action: 140.0 | Reward: 1.8194429894179893 | Qlength: 1.5337287037037037
# Cycle 3 | Action: 80.0 | Reward: 0.375 | Qlength: 0.0
# Cycle 4 | Action: 380.0 | Reward: 0.10526315789473684 | Qlength: 0.0
# Cycle 5 | Action: 80.0 | Reward: 0.625 | Qlength: 0.0
# Cycle 6 | Action: 160.0 | Reward: 0.4375 | Qlength: 0.0
# Cycle 7 | Action: 100.0 | Reward: 1.5420111111111106 | Qlength: 0.5420111111111107
# Cycle 8 | Action: 180.0 | Reward: 0.4166666666666667 | Qlength: 0.0
# Cycle 9 | Action: 360.0 | Reward: 0.19444444444444445 | Qlength: 0.0
# Cycle 10 | Action: 480.0 | Reward: 0.16666666666666666 | Qlength: 0.0
# Cycle 11 | Action: 360.0 | Reward: 0.25 | Qlength: 0.0
# Cycle 12 | Action: 360.0 | Reward: 0.2777777777777778 | Qlength: 0.0
# Cycle 13 | Action: 180.0 | Reward: 0.5 | Qlength: 0.0
# Cycle 14 | Action: 100.0 | Reward: 2.481957407407406 | Qlength: 1.481957407407406
# Cycle 15 | Action: 400.0 | Reward: 0.3003675925925926 | Qlength: 0.00036759259259259134
# Cycle 16 | Action: 340.0 | Reward: 0.3235294117647059 | Qlength: 0.0
# Cycle 17 | Action: 260.0 | Reward: 0.6153846153846154 | Qlength: 0.0
# Cycle 18 | Action: 320.0 | Reward: 0.53125 | Qlength: 0.0
# Cycle 19 | Action: 220.0 | Reward: 0.8182188552188553 | Qlength: 3.7037037037037037e-05
# Cycle 22 | Action: 160.0 | Reward: 5.988717592592592 | Qlength: 5.176217592592592
# Cycle 23 | Action: 280.0 | Reward: 0.32142857142857145 | Qlength: 0.0
# Episode 31 | TotalReward: 15.490626860368733 | TotalBandwidth: 5440.0
# Cycle 0 | Action: 440.0 | Reward: 0.18181818181818182 | Qlength: 0.0
# Cycle 1 | Action: 340.0 | Reward: 0.17647058823529413 | Qlength: 0.0
# Cycle 2 | Action: 400.0 | Reward: 0.1 | Qlength: 0.0
# Cycle 3 | Action: 500.0 | Reward: 0.06 | Qlength: 0.0
# Cycle 4 | Action: 40.0 | Reward: 1.3957749999999995 | Qlength: 0.3957749999999996
# Cycle 5 | Action: 460.0 | Reward: 0.10869565217391304 | Qlength: 0.0
# Cycle 6 | Action: 220.0 | Reward: 0.3181818181818182 | Qlength: 0.0
# Cycle 7 | Action: 260.0 | Reward: 0.38461538461538464 | Qlength: 0.0
# Cycle 8 | Action: 400.0 | Reward: 0.1875 | Qlength: 0.0
# Cycle 9 | Action: 100.0 | Reward: 0.7000009259259259 | Qlength: 9.259259259259259e-07
# Cycle 10 | Action: 320.0 | Reward: 0.25 | Qlength: 0.0
# Cycle 11 | Action: 180.0 | Reward: 0.5 | Qlength: 0.0
# Cycle 12 | Action: 140.0 | Reward: 0.7142866402116402 | Qlength: 9.259259259259259e-07
# Cycle 13 | Action: 100.0 | Reward: 0.9040888888888889 | Qlength: 0.0040888888888888884
# Cycle 14 | Action: 500.0 | Reward: 0.2 | Qlength: 0.0
# Cycle 15 | Action: 500.0 | Reward: 0.24 | Qlength: 0.0
# Cycle 16 | Action: 360.0 | Reward: 0.3055555555555556 | Qlength: 0.0
# Cycle 17 | Action: 500.0 | Reward: 0.32 | Qlength: 0.0
# Cycle 18 | Action: 480.0 | Reward: 0.3541666666666667 | Qlength: 0.0
# Cycle 20 | Action: 400.0 | Reward: 1.2727953703703707 | Qlength: 0.7727953703703707
# Cycle 23 | Action: 160.0 | Reward: 2.751443518518519 | Qlength: 2.188943518518519
# Episode 32 | TotalReward: 8.425394191162159 | TotalBandwidth: 6960.0
# Cycle 0 | Action: 300.0 | Reward: 0.26666666666666666 | Qlength: 0.0
# Cycle 1 | Action: 180.0 | Reward: 0.3333333333333333 | Qlength: 0.0
# Cycle 2 | Action: 500.0 | Reward: 0.08 | Qlength: 0.0
# Cycle 3 | Action: 220.0 | Reward: 0.13636363636363635 | Qlength: 0.0
# Cycle 4 | Action: 40.0 | Reward: 1.3957749999999995 | Qlength: 0.3957749999999996
# Cycle 5 | Action: 320.0 | Reward: 0.15625 | Qlength: 0.0
# Cycle 7 | Action: 340.0 | Reward: 0.9370667211328974 | Qlength: 0.6429490740740739
# Cycle 8 | Action: 160.0 | Reward: 0.46875 | Qlength: 0.0
# Cycle 9 | Action: 480.0 | Reward: 0.14583333333333334 | Qlength: 0.0
# Cycle 10 | Action: 320.0 | Reward: 0.25 | Qlength: 0.0
# Cycle 11 | Action: 340.0 | Reward: 0.2647058823529412 | Qlength: 0.0
# Cycle 12 | Action: 180.0 | Reward: 0.5555555555555556 | Qlength: 0.0
# Cycle 13 | Action: 420.0 | Reward: 0.21428571428571427 | Qlength: 0.0
# Cycle 14 | Action: 100.0 | Reward: 2.481957407407406 | Qlength: 1.481957407407406
# Cycle 19 | Action: 280.0 | Reward: 2.187675661375661 | Qlength: 1.544818518518518
# Cycle 20 | Action: 320.0 | Reward: 0.625 | Qlength: 0.0
# Cycle 21 | Action: 440.0 | Reward: 0.36363636363636365 | Qlength: 0.0
# Cycle 22 | Action: 340.0 | Reward: 0.38235294117647056 | Qlength: 0.0
# Episode 33 | TotalReward: 5.245208216619979 | TotalBandwidth: 5620.0
# Cycle 0 | Action: 440.0 | Reward: 0.18181818181818182 | Qlength: 0.0
# Cycle 1 | Action: 320.0 | Reward: 0.1875 | Qlength: 0.0
# Cycle 2 | Action: 80.0 | Reward: 0.5 | Qlength: 0.0
# Cycle 3 | Action: 360.0 | Reward: 0.08333333333333333 | Qlength: 0.0
# Cycle 4 | Action: 360.0 | Reward: 0.1111111111111111 | Qlength: 0.0
# Cycle 5 | Action: 240.0 | Reward: 0.20833333333333334 | Qlength: 0.0
# Cycle 6 | Action: 440.0 | Reward: 0.1590909090909091 | Qlength: 0.0
# Cycle 7 | Action: 460.0 | Reward: 0.21739130434782608 | Qlength: 0.0
# Cycle 8 | Action: 480.0 | Reward: 0.15625 | Qlength: 0.0
# Cycle 9 | Action: 500.0 | Reward: 0.14 | Qlength: 0.0
# Cycle 10 | Action: 220.0 | Reward: 0.36363636363636365 | Qlength: 0.0
# Cycle 11 | Action: 240.0 | Reward: 0.375 | Qlength: 0.0
# Cycle 12 | Action: 220.0 | Reward: 0.45454545454545453 | Qlength: 0.0
# Cycle 13 | Action: 360.0 | Reward: 0.25 | Qlength: 0.0
# Cycle 14 | Action: 280.0 | Reward: 0.35714285714285715 | Qlength: 0.0
# Cycle 15 | Action: 280.0 | Reward: 0.42857142857142855 | Qlength: 0.0
# Cycle 16 | Action: 140.0 | Reward: 0.7857559523809524 | Qlength: 4.166666666666667e-05
# Cycle 17 | Action: 240.0 | Reward: 0.6666666666666666 | Qlength: 0.0
# Cycle 18 | Action: 340.0 | Reward: 0.5 | Qlength: 0.0
# Cycle 19 | Action: 480.0 | Reward: 0.375 | Qlength: 0.0
# Cycle 21 | Action: 300.0 | Reward: 1.6188157407407409 | Qlength: 1.0854824074074074
# Cycle 22 | Action: 500.0 | Reward: 0.26 | Qlength: 0.0
# Cycle 23 | Action: 140.0 | Reward: 0.6428571428571429 | Qlength: 0.0
# Episode 34 | TotalReward: 8.022819779576302 | TotalBandwidth: 7560.0
# Cycle 0 | Action: 360.0 | Reward: 0.2222222222222222 | Qlength: 0.0
# Cycle 1 | Action: 500.0 | Reward: 0.12 | Qlength: 0.0
# Cycle 2 | Action: 380.0 | Reward: 0.10526315789473684 | Qlength: 0.0
# Cycle 3 | Action: 500.0 | Reward: 0.06 | Qlength: 0.0
# Cycle 4 | Action: 200.0 | Reward: 0.2 | Qlength: 0.0
# Cycle 5 | Action: 220.0 | Reward: 0.22727272727272727 | Qlength: 0.0
# Cycle 6 | Action: 400.0 | Reward: 0.175 | Qlength: 0.0
# Cycle 7 | Action: 360.0 | Reward: 0.2777777777777778 | Qlength: 0.0
# Cycle 9 | Action: 160.0 | Reward: 2.183176851851851 | Qlength: 1.7456768518518506
# Cycle 10 | Action: 100.0 | Reward: 0.8001990740740741 | Qlength: 0.0001990740740740741
# Cycle 11 | Action: 300.0 | Reward: 0.3 | Qlength: 0.0
# Cycle 12 | Action: 460.0 | Reward: 0.21739130434782608 | Qlength: 0.0
# Cycle 13 | Action: 360.0 | Reward: 0.25 | Qlength: 0.0
# Cycle 14 | Action: 380.0 | Reward: 0.2631578947368421 | Qlength: 0.0
# Cycle 15 | Action: 420.0 | Reward: 0.2857142857142857 | Qlength: 0.0
# Cycle 16 | Action: 400.0 | Reward: 0.275 | Qlength: 0.0
# Cycle 21 | Action: 220.0 | Reward: 3.2764171717171724 | Qlength: 2.5491444444444453
# Cycle 22 | Action: 200.0 | Reward: 0.65 | Qlength: 0.0
# Cycle 23 | Action: 360.0 | Reward: 0.25 | Qlength: 0.0
# Episode 35 | TotalReward: 5.138592467609516 | TotalBandwidth: 6620.0
# Cycle 0 | Action: 180.0 | Reward: 0.4444444444444444 | Qlength: 0.0
# ...
# Cycle 23 | Action: 120.0 | Reward: 5.882873148148139 | Qlength: 5.132873148148139
# Episode 989 | TotalReward: 62.78684563492051 | TotalBandwidth: 2380.0
# Cycle 1 | Action: 80.0 | Reward: 8.615885185185148 | Qlength: 7.865885185185148
# Cycle 3 | Action: 60.0 | Reward: 5.708616666666658 | Qlength: 5.208616666666658
# Cycle 5 | Action: 120.0 | Reward: 2.619780555555554 | Qlength: 2.2031138888888875
# Cycle 7 | Action: 120.0 | Reward: 8.690591666666647 | Qlength: 7.857258333333314
# Cycle 9 | Action: 120.0 | Reward: 3.7513333333333367 | Qlength: 3.1680000000000033
# Cycle 11 | Action: 120.0 | Reward: 5.848469444444436 | Qlength: 5.098469444444436
# Cycle 13 | Action: 120.0 | Reward: 6.071308333333325 | Qlength: 5.321308333333325
# Cycle 15 | Action: 140.0 | Reward: 8.392351190476177 | Qlength: 7.53520833333332
# Cycle 16 | Action: 160.0 | Reward: 0.6875 | Qlength: 0.0
# Cycle 17 | Action: 160.0 | Reward: 4.200542592592592 | Qlength: 3.200542592592592
# Cycle 19 | Action: 200.0 | Reward: 8.65597407407406 | Qlength: 7.755974074074059
# Cycle 21 | Action: 200.0 | Reward: 4.661619444444446 | Qlength: 3.8616194444444454
# Cycle 23 | Action: 120.0 | Reward: 5.882873148148139 | Qlength: 5.132873148148139
# Episode 990 | TotalReward: 62.78684563492051 | TotalBandwidth: 2380.0
# Cycle 1 | Action: 80.0 | Reward: 8.615885185185148 | Qlength: 7.865885185185148
# Cycle 3 | Action: 60.0 | Reward: 5.708616666666658 | Qlength: 5.208616666666658
# Cycle 5 | Action: 120.0 | Reward: 2.619780555555554 | Qlength: 2.2031138888888875
# Cycle 7 | Action: 120.0 | Reward: 8.690591666666647 | Qlength: 7.857258333333314
# Cycle 9 | Action: 120.0 | Reward: 3.7513333333333367 | Qlength: 3.1680000000000033
# Cycle 11 | Action: 120.0 | Reward: 5.848469444444436 | Qlength: 5.098469444444436
# Cycle 13 | Action: 120.0 | Reward: 6.071308333333325 | Qlength: 5.321308333333325
# Cycle 14 | Action: 380.0 | Reward: 0.2631578947368421 | Qlength: 0.0
# Cycle 16 | Action: 140.0 | Reward: 5.921621693121688 | Qlength: 5.1359074074074025
# Cycle 17 | Action: 160.0 | Reward: 4.200542592592592 | Qlength: 3.200542592592592
# Cycle 19 | Action: 200.0 | Reward: 8.65597407407406 | Qlength: 7.755974074074059
# Cycle 21 | Action: 200.0 | Reward: 4.661619444444446 | Qlength: 3.8616194444444454
# Cycle 23 | Action: 120.0 | Reward: 5.882873148148139 | Qlength: 5.132873148148139
# Episode 991 | TotalReward: 59.89177403230286 | TotalBandwidth: 2680.0
# Cycle 1 | Action: 80.0 | Reward: 8.615885185185148 | Qlength: 7.865885185185148
# Cycle 3 | Action: 60.0 | Reward: 5.708616666666658 | Qlength: 5.208616666666658
# Cycle 4 | Action: 120.0 | Reward: 0.3333333333333333 | Qlength: 0.0
# Cycle 6 | Action: 120.0 | Reward: 3.6794037037037106 | Qlength: 3.096070370370377
# Cycle 8 | Action: 120.0 | Reward: 4.095951851851855 | Qlength: 3.470951851851855
# Cycle 10 | Action: 120.0 | Reward: 4.547406481481482 | Qlength: 3.8807398148148153
# Cycle 12 | Action: 120.0 | Reward: 8.626459259259244 | Qlength: 7.79312592592591
# Cycle 14 | Action: 120.0 | Reward: 8.382949074074048 | Qlength: 7.549615740740714
# Cycle 16 | Action: 140.0 | Reward: 5.921621693121688 | Qlength: 5.1359074074074025
# Cycle 17 | Action: 160.0 | Reward: 4.200542592592592 | Qlength: 3.200542592592592
# Cycle 19 | Action: 200.0 | Reward: 8.65597407407406 | Qlength: 7.755974074074059
# Cycle 21 | Action: 200.0 | Reward: 4.661619444444446 | Qlength: 3.8616194444444454
# Cycle 23 | Action: 120.0 | Reward: 5.88739166666666 | Qlength: 5.13739166666666
# Episode 992 | TotalReward: 62.31715502645492 | TotalBandwidth: 2420.0
# Cycle 1 | Action: 80.0 | Reward: 8.615885185185148 | Qlength: 7.865885185185148
# Cycle 3 | Action: 60.0 | Reward: 5.708616666666658 | Qlength: 5.208616666666658
# Cycle 5 | Action: 120.0 | Reward: 2.619780555555554 | Qlength: 2.2031138888888875
# Cycle 7 | Action: 120.0 | Reward: 8.690591666666647 | Qlength: 7.857258333333314
# Cycle 9 | Action: 120.0 | Reward: 3.7513333333333367 | Qlength: 3.1680000000000033
# Cycle 11 | Action: 120.0 | Reward: 5.848469444444436 | Qlength: 5.098469444444436
# Cycle 13 | Action: 120.0 | Reward: 6.071308333333325 | Qlength: 5.321308333333325
# Cycle 15 | Action: 140.0 | Reward: 8.392351190476177 | Qlength: 7.53520833333332
# Cycle 16 | Action: 160.0 | Reward: 0.6875 | Qlength: 0.0
# Cycle 17 | Action: 160.0 | Reward: 4.200542592592592 | Qlength: 3.200542592592592
# Cycle 19 | Action: 200.0 | Reward: 8.65597407407406 | Qlength: 7.755974074074059
# Cycle 21 | Action: 200.0 | Reward: 4.661619444444446 | Qlength: 3.8616194444444454
# Cycle 23 | Action: 120.0 | Reward: 5.882873148148139 | Qlength: 5.132873148148139
# Episode 993 | TotalReward: 62.78684563492051 | TotalBandwidth: 2220.0
# Cycle 1 | Action: 80.0 | Reward: 8.615885185185148 | Qlength: 7.865885185185148
# Cycle 3 | Action: 60.0 | Reward: 5.708616666666658 | Qlength: 5.208616666666658
# Cycle 4 | Action: 120.0 | Reward: 0.3333333333333333 | Qlength: 0.0
# Cycle 6 | Action: 120.0 | Reward: 3.6794037037037106 | Qlength: 3.096070370370377
# Cycle 8 | Action: 120.0 | Reward: 4.095951851851855 | Qlength: 3.470951851851855
# Cycle 10 | Action: 120.0 | Reward: 4.547406481481482 | Qlength: 3.8807398148148153
# Cycle 12 | Action: 120.0 | Reward: 8.626459259259244 | Qlength: 7.79312592592591
# Cycle 14 | Action: 120.0 | Reward: 8.382949074074048 | Qlength: 7.549615740740714
# Cycle 16 | Action: 140.0 | Reward: 5.921621693121688 | Qlength: 5.1359074074074025
# Cycle 17 | Action: 160.0 | Reward: 4.200542592592592 | Qlength: 3.200542592592592
# Cycle 19 | Action: 200.0 | Reward: 8.65597407407406 | Qlength: 7.755974074074059
# Cycle 21 | Action: 200.0 | Reward: 4.661619444444446 | Qlength: 3.8616194444444454
# Cycle 23 | Action: 120.0 | Reward: 5.88739166666666 | Qlength: 5.13739166666666
# Episode 994 | TotalReward: 62.31715502645492 | TotalBandwidth: 2320.0
# Cycle 1 | Action: 80.0 | Reward: 8.615885185185148 | Qlength: 7.865885185185148
# Cycle 3 | Action: 60.0 | Reward: 5.708616666666658 | Qlength: 5.208616666666658
# Cycle 4 | Action: 120.0 | Reward: 0.3333333333333333 | Qlength: 0.0
# Cycle 6 | Action: 120.0 | Reward: 3.6794037037037106 | Qlength: 3.096070370370377
# Cycle 8 | Action: 120.0 | Reward: 4.095951851851855 | Qlength: 3.470951851851855
# Cycle 10 | Action: 120.0 | Reward: 4.547406481481482 | Qlength: 3.8807398148148153
# Cycle 12 | Action: 120.0 | Reward: 8.626459259259244 | Qlength: 7.79312592592591
# Cycle 14 | Action: 120.0 | Reward: 8.382949074074048 | Qlength: 7.549615740740714
# Cycle 16 | Action: 140.0 | Reward: 5.921621693121688 | Qlength: 5.1359074074074025
# Cycle 17 | Action: 160.0 | Reward: 4.200542592592592 | Qlength: 3.200542592592592
# Cycle 19 | Action: 200.0 | Reward: 8.65597407407406 | Qlength: 7.755974074074059
# Cycle 21 | Action: 200.0 | Reward: 4.661619444444446 | Qlength: 3.8616194444444454
# Cycle 23 | Action: 120.0 | Reward: 5.88739166666666 | Qlength: 5.13739166666666
# Episode 995 | TotalReward: 62.31715502645492 | TotalBandwidth: 2400.0
# Cycle 1 | Action: 80.0 | Reward: 8.615885185185148 | Qlength: 7.865885185185148
# Cycle 3 | Action: 60.0 | Reward: 5.708616666666658 | Qlength: 5.208616666666658
# Cycle 4 | Action: 120.0 | Reward: 0.3333333333333333 | Qlength: 0.0
# Cycle 6 | Action: 120.0 | Reward: 3.6794037037037106 | Qlength: 3.096070370370377
# Cycle 8 | Action: 120.0 | Reward: 4.095951851851855 | Qlength: 3.470951851851855
# Cycle 10 | Action: 120.0 | Reward: 4.547406481481482 | Qlength: 3.8807398148148153
# Cycle 13 | Action: 120.0 | Reward: 6.071308333333325 | Qlength: 5.321308333333325
# Cycle 15 | Action: 140.0 | Reward: 8.392351190476177 | Qlength: 7.53520833333332
# Cycle 16 | Action: 160.0 | Reward: 0.6875 | Qlength: 0.0
# Cycle 17 | Action: 160.0 | Reward: 4.200542592592592 | Qlength: 3.200542592592592
# Cycle 19 | Action: 200.0 | Reward: 8.65597407407406 | Qlength: 7.755974074074059
# Cycle 21 | Action: 200.0 | Reward: 4.661619444444446 | Qlength: 3.8616194444444454
# Cycle 23 | Action: 120.0 | Reward: 5.88739166666666 | Qlength: 5.13739166666666
# Episode 996 | TotalReward: 54.53728452380944 | TotalBandwidth: 2220.0
# Cycle 1 | Action: 80.0 | Reward: 8.615885185185148 | Qlength: 7.865885185185148
# Cycle 3 | Action: 60.0 | Reward: 5.708616666666658 | Qlength: 5.208616666666658
# Cycle 4 | Action: 120.0 | Reward: 0.3333333333333333 | Qlength: 0.0
# Cycle 6 | Action: 120.0 | Reward: 3.6794037037037106 | Qlength: 3.096070370370377
# Cycle 8 | Action: 120.0 | Reward: 4.095951851851855 | Qlength: 3.470951851851855
# Cycle 10 | Action: 120.0 | Reward: 4.547406481481482 | Qlength: 3.8807398148148153
# Cycle 12 | Action: 120.0 | Reward: 8.626459259259244 | Qlength: 7.79312592592591
# Cycle 14 | Action: 120.0 | Reward: 8.382949074074048 | Qlength: 7.549615740740714
# Cycle 16 | Action: 140.0 | Reward: 5.921621693121688 | Qlength: 5.1359074074074025
# Cycle 17 | Action: 160.0 | Reward: 4.200542592592592 | Qlength: 3.200542592592592
# Cycle 19 | Action: 200.0 | Reward: 8.65597407407406 | Qlength: 7.755974074074059
# Cycle 21 | Action: 200.0 | Reward: 4.661619444444446 | Qlength: 3.8616194444444454
# Cycle 23 | Action: 120.0 | Reward: 5.882873148148139 | Qlength: 5.132873148148139
# Episode 997 | TotalReward: 62.3126365079364 | TotalBandwidth: 2240.0
# Cycle 1 | Action: 80.0 | Reward: 8.615885185185148 | Qlength: 7.865885185185148
# Cycle 3 | Action: 60.0 | Reward: 5.708616666666658 | Qlength: 5.208616666666658
# Cycle 4 | Action: 120.0 | Reward: 0.3333333333333333 | Qlength: 0.0
# Cycle 6 | Action: 120.0 | Reward: 3.6794037037037106 | Qlength: 3.096070370370377
# Cycle 8 | Action: 120.0 | Reward: 4.095951851851855 | Qlength: 3.470951851851855
# Cycle 10 | Action: 120.0 | Reward: 4.547406481481482 | Qlength: 3.8807398148148153
# Cycle 12 | Action: 120.0 | Reward: 8.626459259259244 | Qlength: 7.79312592592591
# Cycle 14 | Action: 120.0 | Reward: 8.382949074074048 | Qlength: 7.549615740740714
# Cycle 16 | Action: 140.0 | Reward: 5.921621693121688 | Qlength: 5.1359074074074025
# Cycle 17 | Action: 160.0 | Reward: 4.200542592592592 | Qlength: 3.200542592592592
# Cycle 19 | Action: 200.0 | Reward: 8.65597407407406 | Qlength: 7.755974074074059
# Cycle 21 | Action: 200.0 | Reward: 4.661619444444446 | Qlength: 3.8616194444444454
# Cycle 23 | Action: 120.0 | Reward: 5.882873148148139 | Qlength: 5.132873148148139
# Episode 998 | TotalReward: 62.3126365079364 | TotalBandwidth: 2400.0
# Cycle 1 | Action: 80.0 | Reward: 8.615885185185148 | Qlength: 7.865885185185148
# Cycle 3 | Action: 60.0 | Reward: 5.708616666666658 | Qlength: 5.208616666666658
# Cycle 5 | Action: 120.0 | Reward: 2.619780555555554 | Qlength: 2.2031138888888875
# Cycle 7 | Action: 120.0 | Reward: 8.690591666666647 | Qlength: 7.857258333333314
# Cycle 9 | Action: 120.0 | Reward: 3.7513333333333367 | Qlength: 3.1680000000000033
# Cycle 11 | Action: 120.0 | Reward: 5.848469444444436 | Qlength: 5.098469444444436
# Cycle 13 | Action: 120.0 | Reward: 6.071308333333325 | Qlength: 5.321308333333325
# Cycle 15 | Action: 140.0 | Reward: 8.392351190476177 | Qlength: 7.53520833333332
# Cycle 16 | Action: 160.0 | Reward: 0.6875 | Qlength: 0.0
# Cycle 17 | Action: 160.0 | Reward: 4.200542592592592 | Qlength: 3.200542592592592
# Cycle 19 | Action: 200.0 | Reward: 8.65597407407406 | Qlength: 7.755974074074059
# Cycle 21 | Action: 200.0 | Reward: 4.661619444444446 | Qlength: 3.8616194444444454
# Cycle 23 | Action: 120.0 | Reward: 5.882873148148139 | Qlength: 5.132873148148139
# Episode 999 | TotalReward: 62.78684563492051 | TotalBandwidth: 2260.0
# Cycle 0 | Action: 20.0 | Reward: -1 | TotalReward: -1.0 | p_vio: 0.945 | p_drop: 0.9169444444444445 | Qlength: 61.0
# Cycle 1 | Action: 80.0 | Reward: 8.615885185185148 | Qlength: 7.865885185185148
# Cycle 1 | Action: 80.0 | Reward: 8.615885185185148 | TotalReward: 7.615885185185148 | p_vio: 0.08861111111111111 | p_drop: 0.0033333333333333335 | Qlength: 0.0
# Cycle 2 | Action: 20.0 | Reward: -1 | TotalReward: 6.615885185185148 | p_vio: 0.8352777777777778 | p_drop: 0.7494444444444445 | Qlength: 61.0
# Cycle 3 | Action: 60.0 | Reward: 5.708616666666658 | Qlength: 5.208616666666658
# Cycle 3 | Action: 60.0 | Reward: 5.708616666666658 | TotalReward: 12.324501851851807 | p_vio: 0.059166666666666666 | p_drop: 0.0025 | Qlength: 0.0
# Cycle 4 | Action: 60.0 | Reward: 0.6666740740740741 | Qlength: 7.4074074074074075e-06
# Cycle 4 | Action: 60.0 | Reward: 0.6666740740740741 | TotalReward: 12.99117592592588 | p_vio: 0.0 | p_drop: 0.0 | Qlength: 0.0
# Cycle 5 | Action: 60.0 | Reward: 0.8345953703703705 | Qlength: 0.001262037037037037
# Cycle 5 | Action: 60.0 | Reward: 0.8345953703703705 | TotalReward: 13.825771296296251 | p_vio: 0.0 | p_drop: 0.0 | Qlength: 0.0
# Cycle 6 | Action: 40.0 | Reward: -1 | TotalReward: 12.825771296296251 | p_vio: 0.8894444444444445 | p_drop: 0.8344444444444444 | Qlength: 61.0
# Cycle 7 | Action: 120.0 | Reward: 8.690591666666647 | Qlength: 7.857258333333314
# Cycle 7 | Action: 120.0 | Reward: 8.690591666666647 | TotalReward: 21.516362962962898 | p_vio: 0.08944444444444444 | p_drop: 0.0044444444444444444 | Qlength: 0.0
# Cycle 8 | Action: 40.0 | Reward: -1 | TotalReward: 20.516362962962898 | p_vio: 0.9058333333333334 | p_drop: 0.8577777777777778 | Qlength: 61.0
# Cycle 9 | Action: 120.0 | Reward: 3.7513333333333367 | Qlength: 3.1680000000000033
# Cycle 9 | Action: 120.0 | Reward: 3.7513333333333367 | TotalReward: 24.267696296296236 | p_vio: 0.035833333333333335 | p_drop: 0.001388888888888889 | Qlength: 0.0
# Cycle 10 | Action: 0.0 | Reward: -1 | TotalReward: 23.267696296296236 | p_vio: 0.9586111111111111 | p_drop: 0.9377777777777778 | Qlength: 61.0
# Cycle 11 | Action: 120.0 | Reward: 5.848469444444436 | Qlength: 5.098469444444436
# Cycle 11 | Action: 120.0 | Reward: 5.848469444444436 | TotalReward: 29.116165740740673 | p_vio: 0.05638888888888889 | p_drop: 0.0025 | Qlength: 0.0
# Cycle 12 | Action: 0.0 | Reward: -1 | TotalReward: 28.116165740740673 | p_vio: 0.9669444444444445 | p_drop: 0.9497222222222222 | Qlength: 61.0
# Cycle 13 | Action: 120.0 | Reward: 6.071308333333325 | Qlength: 5.321308333333325
# Cycle 13 | Action: 120.0 | Reward: 6.071308333333325 | TotalReward: 34.187474074074 | p_vio: 0.060833333333333336 | p_drop: 0.0030555555555555557 | Qlength: 0.0
# Cycle 14 | Action: 20.0 | Reward: -1 | TotalReward: 33.187474074074 | p_vio: 0.9577777777777777 | p_drop: 0.9366666666666666 | Qlength: 61.0
# Cycle 15 | Action: 140.0 | Reward: 8.392351190476177 | Qlength: 7.53520833333332
# Cycle 15 | Action: 140.0 | Reward: 8.392351190476177 | TotalReward: 41.57982526455017 | p_vio: 0.085 | p_drop: 0.003611111111111111 | Qlength: 0.0
# Cycle 16 | Action: 160.0 | Reward: 0.6875 | Qlength: 0.0
# Cycle 16 | Action: 160.0 | Reward: 0.6875 | TotalReward: 42.26732526455017 | p_vio: 0.0 | p_drop: 0.0 | Qlength: 0.0
# Cycle 17 | Action: 160.0 | Reward: 4.200542592592592 | Qlength: 3.200542592592592
# Cycle 17 | Action: 160.0 | Reward: 4.200542592592592 | TotalReward: 46.467867857142764 | p_vio: 0.0 | p_drop: 0.0 | Qlength: 5.406666666666666
# Cycle 18 | Action: 160.0 | Reward: -1 | TotalReward: 45.467867857142764 | p_vio: 0.6991666666666667 | p_drop: 0.5172222222222222 | Qlength: 61.0
# Cycle 19 | Action: 200.0 | Reward: 8.65597407407406 | Qlength: 7.755974074074059
# Cycle 19 | Action: 200.0 | Reward: 8.65597407407406 | TotalReward: 54.12384193121682 | p_vio: 0.08611111111111111 | p_drop: 0.0038888888888888888 | Qlength: 0.0
# Cycle 20 | Action: 120.0 | Reward: -1 | TotalReward: 53.12384193121682 | p_vio: 0.9586111111111111 | p_drop: 0.9380555555555555 | Qlength: 61.0
# Cycle 21 | Action: 200.0 | Reward: 4.661619444444446 | Qlength: 3.8616194444444454
# Cycle 21 | Action: 200.0 | Reward: 4.661619444444446 | TotalReward: 57.78546137566127 | p_vio: 0.0425 | p_drop: 0.0016666666666666668 | Qlength: 0.0
# Cycle 22 | Action: 100.0 | Reward: -1 | TotalReward: 56.78546137566127 | p_vio: 0.8888888888888888 | p_drop: 0.8327777777777777 | Qlength: 61.0
# Cycle 23 | Action: 120.0 | Reward: 5.88739166666666 | Qlength: 5.13739166666666
# Cycle 23 | Action: 120.0 | Reward: 5.88739166666666 | TotalReward: 62.67285304232793 | p_vio: 0.057777777777777775 | p_drop: 0.0025 | Qlength: 0.0
# Episode 1000 | TotalReward: 62.67285304232793 | TotalBandwidth: 2240.0
# Training finished. Saved model to dqn_policy_final.pth
